# %% [markdown]
# # Multimodal Network
#
# Create GNN for each of the dimensions and later combine them into a single network.
#
# 1. Each dimension is a separate graph and gets its own GNN.
# 2. Dimensions are connected in a MLP layer.
#
# Add the Gini value as a node-feature and masking it to prevent data-leakage.

# %% [markdown]
# #### Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch.optim as optim
from torch.utils.data import TensorDataset, random_split
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
import os
import country_converter as coco
import functools
import os
from torchmetrics.regression import MeanAbsolutePercentageError

# Set up device (is available use GPU to speed up computations)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

os.chdir('/home/jovyan/dlss-project')
print("Current working directory:", os.getcwd())
# Out:
# cuda
# Current working directory: /home/jovyan/dlss-project

# %% [markdown]
# ## Data

# %%
path_geo_edges = "data_collection/geography/edges_yearly_dist_enc.parquet"
path_geo_nodes = "data_collection/geography/nodes_enc.parquet"
df_geo_edges = pd.read_parquet(path_geo_edges)
df_geo_nodes = pd.read_parquet(path_geo_nodes)

path_pol_edges = "data_collection/political/data/edge_features.parquet"
path_pol_nodes = "data_collection/political/data/node_features.parquet"
df_pol_edges = pd.read_parquet(path_pol_edges)
df_pol_nodes = pd.read_parquet(path_pol_nodes)

path_cult_edges = "data_collection/culture/culture_edges.parquet"
path_cult_nodes = "data_collection/culture/culture_nodes.parquet"
df_cult_edges = pd.read_parquet(path_cult_edges)
df_cult_nodes = pd.read_parquet(path_cult_nodes)

path_lang_edges = "data_collection/culture/language_religion_edges.parquet"
path_lang_nodes = "data_collection/culture/language_religion_nodes.parquet"
df_lang_edges = pd.read_parquet(path_lang_edges)
df_lang_nodes = pd.read_parquet(path_lang_nodes)

path_eco_edges = "data_collection/economics/edges_economics.parquet"
path_eco_nodes = "data_collection/economics/nodes_economics.parquet"
df_eco_edges = pd.read_parquet(path_eco_edges)
df_eco_nodes = pd.read_parquet(path_eco_nodes)

path_gini = "data_collection/gini.parquet"
df_gini = pd.read_parquet(path_gini)
df_gini = df_gini[df_gini['year'].between(2000, 2022)].reset_index(drop=True)

# %%
@functools.lru_cache(maxsize=1)
def get_un_countries():
    """Cache UN member countries to avoid repeated lookups"""
    iso3 = coco.CountryConverter().data[coco.CountryConverter().data['UNmember'].notna()]['ISO3'].dropna().tolist()
    unnumeric = coco.CountryConverter().data[coco.CountryConverter().data['UNmember'].notna()]['UNcode'].dropna().tolist()
    return iso3, unnumeric

@functools.lru_cache(maxsize=1000)
def convert_country_code(country, target_format='UNnumeric'):
    """Cache country code conversions"""
    return coco.convert(names=country, to=target_format, not_found=None)

def df_preparation(edge_df, node_df, edge_country_a_col, edge_country_b_col, node_country_col, year_col="year"):
    # Get UN countries once
    uno_iso3_codes, uno_unnumeric_codes = get_un_countries()

    # Pre-filter dataframes
    edge_mask = edge_df[edge_country_a_col].isin(uno_iso3_codes) & edge_df[edge_country_b_col].isin(uno_iso3_codes)
    node_mask = node_df[node_country_col].isin(uno_iso3_codes)

    edge_df = edge_df[edge_mask].copy()
    node_df = node_df[node_mask].copy()

    # Ensure year is int before unique extraction
    edge_df[year_col] = edge_df[year_col].astype(int)
    node_df[year_col] = node_df[year_col].astype(int)

    # Vectorized country code conversion
    unique_countries_edges = pd.concat([edge_df[edge_country_a_col], edge_df[edge_country_b_col]]).unique()
    unique_countries_nodes = node_df[node_country_col].unique()
    all_unique_countries = np.unique(np.concatenate([unique_countries_edges, unique_countries_nodes]))

    country_to_id_map = dict(zip(
        all_unique_countries,
        coco.convert(all_unique_countries.tolist(), to='UNnumeric', not_found=None)
    ))

    # Apply mapping
    edge_df['country_id_a'] = edge_df[edge_country_a_col].map(country_to_id_map)
    edge_df['country_id_b'] = edge_df[edge_country_b_col].map(country_to_id_map)
    node_df['country_id'] = node_df[node_country_col].map(country_to_id_map)

    # Drop any rows where mapping failed (shouldn't if filters were correct)
    edge_df = edge_df.dropna(subset=['country_id_a', 'country_id_b'])
    node_df = node_df.dropna(subset=['country_id'])

    # Cast country_id to int
    edge_df['country_id_a'] = edge_df['country_id_a'].astype(int)
    edge_df['country_id_b'] = edge_df['country_id_b'].astype(int)
    node_df['country_id'] = node_df['country_id'].astype(int)
    
    edge_features_cols = [
        col for col in edge_df.columns
        if col not in [edge_country_a_col, edge_country_b_col, year_col, 'country_id_a', 'country_id_b']
    ]
    node_features_cols = [
        col for col in node_df.columns
        if col not in [node_country_col, year_col, 'country_id']
    ]
    
    edge_df_processed = edge_df.copy()[['country_id_a', 'country_id_b', year_col] + edge_features_cols]
    node_df_processed = node_df.copy()[['country_id', year_col] + node_features_cols]
    
    return node_df_processed, edge_df_processed

def preprocess_gini(df_gini, year_col='year', country_col='country', gini_col='gini'):
    uno_iso3_codes, uno_unnumeric_codes = get_un_countries()

    # Filter Gini data for UN countries
    df_gini = df_gini[df_gini[country_col].isin(uno_iso3_codes)].copy()
    
    # Convert country codes to UN numeric
    df_gini['country_id'] = df_gini[country_col].map(lambda x: convert_country_code(x, 'UNnumeric'))
    
    df_gini = df_gini.sort_values(by=['country_id']).reset_index(drop=True)
    
    # Drop rows with NaN country_id
    df_gini = df_gini.dropna(subset=['country_id'])
    
    # Normalize Gini values to [0, 1] range for each year
    df_gini[gini_col] = df_gini[gini_col] / 100
    
    # create mask column to indicate if country exists in this year
    df_gini['exists'] = 1
    df_gini.loc[df_gini[gini_col].isna(), 'exists'] = 0
    
    df_gini.loc[df_gini[gini_col].isna(), gini_col] = 0  # Fill NaN Gini values with 0
    
    return df_gini[['country_id', year_col, gini_col, 'exists']].copy()

def create_data_yearly(node_df, edge_df, year, mask_col, year_col='year',):
        
    edge_df_year = edge_df[edge_df[year_col] == year]
    node_df_year = node_df[node_df[year_col] == year].copy()  # copy because we'll potentially modify
    
    # drop dupicate rows in node_df_year
    node_df_year = node_df_year.drop_duplicates(subset=['country_id', year_col], keep='first')
            
    # --- Edge features ---
    edge_features_cols = [
        col for col in edge_df_year.columns
        if col not in ['country_id_a', 'country_id_b', year_col]
    ]
    edge_features_df = edge_df_year[edge_features_cols].copy()
    
    # Coerce all edge feature columns to numeric, fill NaN with 0
    edge_features_df = edge_features_df.apply(pd.to_numeric, errors='coerce').fillna(0)
    
    # --- Node features ---
    node_features_cols = [
        col for col in node_df_year.columns
        if col not in ['country_id', year_col, mask_col]
    ]
        
    # Ensure node_df_year is sorted by country_id and align features accordingly
    node_df_year_sorted = node_df_year.sort_values(by='country_id').reset_index(drop=True)
        
    # select only feature columns
    node_df_year_features = node_df_year_sorted[node_features_cols].copy()
    
    mask_col_tensor = torch.tensor(node_df_year_sorted[mask_col].values, dtype=torch.float32)
    
    country_id_tensor = torch.tensor(node_df_year_sorted['country_id'].values, dtype=torch.long)
    
    # --- Tensor creation ---
    edge_features_array = edge_features_df.values.astype(np.float32)
    edge_attr = torch.from_numpy(edge_features_array)

    
    node_df_year_features = node_df_year_features.apply(pd.to_numeric, errors='coerce').fillna(0)
    node_features_tensor = torch.tensor(node_df_year_features.values, dtype=torch.float32)
    
    
    # Build a mapping from country_id to its position in the sorted node list
    country_id_to_pos = {cid: i for i, cid in enumerate(node_df_year_sorted['country_id'].values)}
    
    # Map edge indices to positions in the sorted node list
    edge_index = torch.tensor(
        [
        edge_df_year['country_id_a'].map(country_id_to_pos).values,
        edge_df_year['country_id_b'].map(country_id_to_pos).values
        ],
        dtype=torch.long
    )
    data = Data(x=node_features_tensor, edge_index=edge_index, edge_attr=edge_attr, country_id = country_id_tensor, mask=mask_col_tensor)
    
    return data

def scale_data(node_df, edge_df, node_features_cols, edge_feature_cols):
    """
    Scale node and edge dataframes using StandardScaler.
    """
    # apply standardization to node features
    node_scaler = StandardScaler()
    edge_scaler = StandardScaler()
    
    # fit standard scaler on train set
    
    # create subset of only training rows to fit scaler
    node_df_train_subset = node_df[node_df['train_mask'] == 1]
    node_scaler.fit(node_df_train_subset[node_features_cols])
    
    # filter edge_df to only include training countries
    edge_df_train_subset = edge_df[edge_df['country_id_a'].isin(node_df_train_subset['country_id']) & 
                                   edge_df['country_id_b'].isin(node_df_train_subset['country_id'])]
    edge_scaler.fit(edge_df_train_subset[edge_feature_cols])
    
    # apply scaler to all node dataframes
    node_df[node_features_cols] = node_scaler.transform(node_df[node_features_cols])
    edge_df[edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
    
    return node_df, edge_df

def create_network_data(node_df, edge_df, gini_df):
    uno_iso3_codes, uno_unnumeric_codes = get_un_countries()
    
    # convert boolean columns to int
    bool_cols_nodes = node_df.select_dtypes(include='bool').columns
    if len(bool_cols_nodes) > 0:
        node_df[bool_cols_nodes] = node_df[bool_cols_nodes].astype(int)
    bool_cols_edges = edge_df.select_dtypes(include='bool').columns
    if len(bool_cols_edges) > 0:
        edge_df[bool_cols_edges] = edge_df[bool_cols_edges].astype(int)
    
    # fill in all missing countries with 0 values for the years from 2000 to 2022
    all_years = range(2000, 2023)
    all_countries = uno_unnumeric_codes
    
    # Create a MultiIndex of all combinations
    full_index = pd.MultiIndex.from_product([all_countries, all_years], names=['country_id', 'year'])
    node_df = node_df.set_index(['country_id', 'year'])
    node_df = node_df.reindex(full_index, fill_value=0).reset_index()
        
    # Fill missing feature columns with 0 (if any NaNs)
    node_features_cols = [col for col in node_df.columns if col not in ['country_id', 'year']]
    node_df[node_features_cols] = node_df[node_features_cols].fillna(0)
    
    edge_feature_cols = [col for col in edge_df.columns if col not in ['country_id_a', 'country_id_b', 'year']]
    
    # merge node_df with gini_df
    node_df_merged = node_df.merge(gini_df, on=['country_id', 'year'])
    
    node_df_merged, edge_df = scale_data(node_df_merged, edge_df, node_features_cols, edge_feature_cols)
    
    # generate train, val and test set.
    # set gini to 0 at respected masks
    
    node_df_train = node_df_merged.copy().drop(columns=['val_mask', 'test_mask'], errors='ignore')
    node_df_val = node_df_merged.copy().drop(columns=['train_mask', 'test_mask'], errors='ignore')
    node_df_test = node_df_merged.copy().drop(columns=['train_mask', 'val_mask'], errors='ignore')
    
    # set gini to 0 where train_mask is 1
    node_df_train.loc[gini_df['train_mask'] == 1, 'gini'] = 0
    node_df_val.loc[gini_df['val_mask'] == 1, 'gini'] = 0
    node_df_test.loc[gini_df['test_mask'] == 1, 'gini'] = 0
    
    
    # limit years from 2000 to 2022
    years = [year for year in range(2000, 2023)]
    
    data_dict = {}
    # create data for each year
    
    for year in years:
        data_train = create_data_yearly(node_df_train, edge_df, year, 'train_mask', year_col='year')
        data_val = create_data_yearly(node_df_val, edge_df, year, 'val_mask', year_col='year')
        data_test = create_data_yearly(node_df_test, edge_df, year, 'test_mask', year_col='year')
        data_dict[year] = {
            'train': data_train,
            'val': data_val,
            'test': data_test
        }
    
    return data_dict

def create_gini_data(gini_df, year_col='year'):
    
    gini_dict = {}
    
    for year in range(2000, 2023):
        gini_df_year = gini_df[gini_df[year_col] == year].copy()

        # convert to tensor
        gini_tensor = torch.tensor(gini_df_year['gini'].values, dtype=torch.float32)
        country_id_tensor = torch.tensor(gini_df_year['country_id'].values, dtype=torch.long)
        train_mask_tensor = torch.tensor(gini_df_year['train_mask'].values, dtype=torch.bool)
        val_mask_tensor = torch.tensor(gini_df_year['val_mask'].values, dtype=torch.bool)
        test_mask_tensor = torch.tensor(gini_df_year['test_mask'].values, dtype=torch.bool)
        
        
        
        gini_dict[year] = {
            'train': Data(y=gini_tensor.unsqueeze(1), country_id=country_id_tensor, mask=train_mask_tensor),
            'val': Data(y=gini_tensor.unsqueeze(1), country_id=country_id_tensor, mask=val_mask_tensor),
            'test': Data(y=gini_tensor.unsqueeze(1), country_id=country_id_tensor, mask=test_mask_tensor)
        }
        
    return gini_dict
            

def create_global_gini_masks(gini_df, test_size=0.2, val_size=0.2, random_state=42):
    """
    Split all available (exists==1) rows in gini_df into train/val/test and create mask columns.
    Adds 'train_mask', 'val_mask', 'test_mask' columns to gini_df (0/1 values).
    """
    df = gini_df.copy()
    available_idx = df.index[df['exists'] == 1].tolist()
    train_idx, test_idx = train_test_split(available_idx, test_size=test_size, random_state=random_state)
    train_idx, val_idx = train_test_split(train_idx, test_size=val_size, random_state=random_state)
    
    df['train_mask'] = 0
    df['val_mask'] = 0
    df['test_mask'] = 0
    df.loc[train_idx, 'train_mask'] = 1
    df.loc[val_idx, 'val_mask'] = 1
    df.loc[test_idx, 'test_mask'] = 1
    return df

def create_data(data_combined, gini_df):
    
    # create gini train, val and test masks
    # perform train-val-test split on gini_data for all available values
    
    gini_df = create_global_gini_masks(gini_df, test_size=0.2, val_size=0.2, random_state=42)
    
    data_dict = {}
    
    for modality, data in data_combined.items():
        nodes = data['nodes']
        edges = data['edges']
        data_dict[modality] = create_network_data(nodes, edges, gini_df)
        
    # add gini data
    gini_data = create_gini_data(gini_df)
    data_dict['gini'] = gini_data
    
    data_dict_reform = {}
    # reform data_dict to have years as keys
    for year in range(2000, 2023):
        data_dict_reform[year] = {
            'political': data_dict['political'][year],
            'geography': data_dict['geography'][year],
            'culture': data_dict['culture'][year],
            'language': data_dict['language'][year],
            'economy': data_dict['economy'][year],
            'gini': gini_data[year]
        }
    
    for year in data_dict_reform.keys():
        data_dict_reform[year] = {
            'train': {
                'political': data_dict_reform[year]['political']['train'],
                'geography': data_dict_reform[year]['geography']['train'],
                'culture': data_dict_reform[year]['culture']['train'],
                'language': data_dict_reform[year]['language']['train'],
                'economy': data_dict_reform[year]['economy']['train'],
                'gini': data_dict_reform[year]['gini']['train']
            },
            'val': {
                'political': data_dict_reform[year]['political']['val'],
                'geography': data_dict_reform[year]['geography']['val'],
                'culture': data_dict_reform[year]['culture']['val'],
                'language': data_dict_reform[year]['language']['val'],
                'economy': data_dict_reform[year]['economy']['val'],
                'gini': data_dict_reform[year]['gini']['val']
            },
            'test': {
                'political': data_dict_reform[year]['political']['test'],
                'geography': data_dict_reform[year]['geography']['test'],
                'culture': data_dict_reform[year]['culture']['test'],
                'language': data_dict_reform[year]['language']['test'],
                'economy': data_dict_reform[year]['economy']['test'],
                'gini': data_dict_reform[year]['gini']['test']
            }
        }
        
    return data_dict_reform

# %%
geo_nodes, geo_edges = df_preparation(df_geo_edges, df_geo_nodes, 
                        edge_country_a_col='iso_o', edge_country_b_col='iso_d',
                        node_country_col='code_3', year_col='year')

pol_nodes, pol_edges = df_preparation(df_pol_edges, df_pol_nodes,
                        edge_country_a_col='state1', edge_country_b_col='state2',
                        node_country_col='country', year_col='year')

cul_nodes, cul_edges = df_preparation(df_cult_edges, df_cult_nodes,
                        edge_country_a_col='ISO3_a', edge_country_b_col='ISO3_b',
                        node_country_col='ISO3', year_col='year')

lang_nodes, lang_edges = df_preparation(df_lang_edges, df_lang_nodes,
                        edge_country_a_col='country_a', edge_country_b_col='country_b',
                        node_country_col='ISO3', year_col='year')

eco_nodes, eco_edges = df_preparation(df_eco_edges, df_eco_nodes,
                        edge_country_a_col='src_ISO3', edge_country_b_col='tgt_ISO3',
                        node_country_col='ISO3', year_col='year')

data_combined = {
    'geography': {'nodes': geo_nodes, 'edges': geo_edges},
    'political': {'nodes': pol_nodes, 'edges': pol_edges},
    'culture': {'nodes': cul_nodes, 'edges': cul_edges},
    'language': {'nodes': lang_nodes, 'edges': lang_edges},
    'economy': {'nodes': eco_nodes, 'edges': eco_edges}
}

df_gini_processed = preprocess_gini(df_gini)

# %%
data_dict = create_data(data_combined, df_gini_processed)
# Out:
# /tmp/ipykernel_1555/1569791298.py:139: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   edge_index = torch.tensor(

# %%
data_dict[2000]['train']['political'].x
# Out:
# tensor([[-2.0361, -1.7419, -1.9230,  ..., -2.5128,  0.0000,  0.0000],
#         [-0.7807, -0.5819, -0.7201,  ..., -1.0274,  0.0000,  0.0000],
#         [-1.1020, -1.2743, -1.2865,  ..., -1.4988,  0.0000,  0.0000],
#         ...,
#         [-2.3089, -1.8205, -1.9838,  ..., -0.2482,  0.0000,  0.0000],
#         [-1.3224, -1.3422, -1.4643,  ..., -1.3853,  0.0000,  0.0000],
#         [-0.4780, -0.4534, -0.4815,  ..., -0.8735,  0.0000,  0.0000]])

# %%
# get the dimesions of each network: number of node_features, number of edge-features
network_dimesions = {
    'geography': {
        'node_features': data_dict[2000]['train']['geography'].x.shape[1],
        'edge_features': data_dict[2000]['train']['geography'].edge_attr.shape[1]
    },
    'political': {
        'node_features': data_dict[2000]['train']['political'].x.shape[1],
        'edge_features': data_dict[2000]['train']['political'].edge_attr.shape[1]
    },
    'culture': {
        'node_features': data_dict[2000]['train']['culture'].x.shape[1],
        'edge_features': data_dict[2000]['train']['culture'].edge_attr.shape[1]
    },
    'language': {
        'node_features': data_dict[2000]['train']['language'].x.shape[1],
        'edge_features': data_dict[2000]['train']['language'].edge_attr.shape[1]
    },
    'economy': {
        'node_features': data_dict[2000]['train']['economy'].x.shape[1],
        'edge_features': data_dict[2000]['train']['economy'].edge_attr.shape[1]
        },  # Placeholder for future economy data
}

# %%
network_dimesions
# Out:
# {'geography': {'node_features': 30, 'edge_features': 16},
#  'political': {'node_features': 9, 'edge_features': 5},
#  'culture': {'node_features': 8, 'edge_features': 11},
#  'language': {'node_features': 9, 'edge_features': 2},
#  'economy': {'node_features': 5, 'edge_features': 1}}

# %% [markdown]
# ## Model Setup

# %%
# GNN model for each of the different networks
class DimensionModel(torch.nn.Module):
    def __init__(self, num_node_features, num_edge_features, hidden_size=64, target_size=1, n_gat_layers=2, n_mlp_layers=2):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_node_features = num_node_features
        self.num_edge_features = num_edge_features
        self.target_size = target_size
        # Dynamically create GAT layers
        self.convs = nn.ModuleList()
        self.convs.append(GATv2Conv(self.num_node_features, self.hidden_size, edge_dim=num_edge_features))
        for _ in range(n_gat_layers - 1):
            self.convs.append(GATv2Conv(self.hidden_size, self.hidden_size, edge_dim=num_edge_features))

        # Dynamically create MLP layers
        self.n_mlp_layers = n_mlp_layers
        mlp_layers = []
        for _ in range(n_mlp_layers):
            mlp_layers.append(nn.Linear(self.hidden_size, self.hidden_size))
            mlp_layers.append(nn.ReLU())
            mlp_layers.append(nn.Dropout(0.2))
        self.mlp = nn.Sequential(*mlp_layers)
        
    def forward(self, data):
        x, edge_index, edge_attr = data.x, data.edge_index, data.edge_attr
        for conv in self.convs[:-1]:
            x = conv(x, edge_index, edge_attr=edge_attr)
            x = F.relu(x)
            x = F.dropout(x, training=self.training)
        x = self.convs[-1](x, edge_index, edge_attr=edge_attr)
        if self.n_mlp_layers > 0:
            x = self.mlp(x)  # Apply the fully connected layer
        return x
    
class MultiModalGNNModel(nn.Module):
    def __init__(self, 
                 input_dims,
                 hidden_size=64,
                 final_output_size=1, 
                 n_gat_layers=2,
                 n_dim_mlp_layers=2,
                 combination_method='concat',
                 mlp_variant='default'):
        super().__init__()
        self.combination_method = combination_method

        self.geo_model = DimensionModel(input_dims['geography']['node_features'], input_dims['geography']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.pol_model = DimensionModel(input_dims['political']['node_features'], input_dims['political']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.cult_model = DimensionModel(input_dims['culture']['node_features'], input_dims['culture']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.lang_model = DimensionModel(input_dims['language']['node_features'], input_dims['language']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.eco_model = DimensionModel(input_dims['economy']['node_features'], input_dims['economy']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)

        self.num_modalities = 5
        self.hidden_size = hidden_size

        if self.combination_method == 'attention':
            # Learnable attention weights for each modality
            self.attn_weights = nn.Parameter(torch.ones(self.num_modalities))

        self.fusion_input_size = hidden_size * self.num_modalities if combination_method == 'concat' else hidden_size
        if mlp_variant == 'default':
            self.mlp = nn.Sequential(
                nn.Linear(self.fusion_input_size, 1024),
                nn.BatchNorm1d(1024),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(1024, 256),
                nn.BatchNorm1d(256),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(256, final_output_size)
            )
        elif mlp_variant == 'deep':
            # Deeper MLP variant
            self.mlp = nn.Sequential(
                nn.Linear(self.fusion_input_size, 2048),
                nn.BatchNorm1d(2048),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(2048, 1024),
                nn.BatchNorm1d(1024),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(1024, 512),
                nn.BatchNorm1d(512),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(512, final_output_size)
            )
        elif mlp_variant == 'shallow':
            # Shallow MLP variant
            self.mlp = nn.Sequential(
                nn.Linear(self.fusion_input_size, 512),
                nn.BatchNorm1d(512),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(512, 256),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(256, final_output_size)
            )        
    

    def forward(self, data_dict):
        geo_emb = self.geo_model(data_dict['geography'])
        pol_emb = self.pol_model(data_dict['political'])
        cult_emb = self.cult_model(data_dict['culture'])
        lang_emb = self.lang_model(data_dict['language'])
        eco_emb = self.eco_model(data_dict['economy'])

        embeddings = [geo_emb, pol_emb, cult_emb, lang_emb, eco_emb]

        if self.combination_method == 'concat':
            # Concatenate embeddings along the last dimension
            fused = torch.cat(embeddings, dim=-1)
        elif self.combination_method == 'attention':
            # Stack embeddings: shape [num_nodes, num_modalities, hidden_size]
            stacked = torch.stack(embeddings, dim=1)  # [num_nodes, num_modalities, hidden_size]
            attn = torch.softmax(self.attn_weights, dim=0)  # [num_modalities]
            attn = attn.view(1, self.num_modalities, 1)     # [1, num_modalities, 1] for broadcasting
            fused = (stacked * attn).sum(dim=1)             # [num_nodes, hidden_size]
        output = self.mlp(fused)
        return output

# %% [markdown]
# ## Training Setup

# %%
class EarlyStopping:
    def __init__(self, patience=25, min_delta=0.0001, path='checkpoint.pt', printing=True):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.path = path  # Path to save the best model
        self.printing = printing
        
        # remove model if path already exists
        if os.path.exists(path):
          os.remove(path)
          
          if self.printing:
            print(f"Removing existing model at: {path}")

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            if val_loss < self.best_loss:
                self.save_checkpoint(val_loss, model)
                self.best_loss = val_loss
                self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        torch.save(model.state_dict(), self.path)
        if self.printing:
            print(f'Validation loss decreased ({self.best_loss:.6f} --> {val_loss:.6f}).  Saving model ...')
        
        
def train_gnn(epochs, model, optimizer, criterion, dataloader, early_stopper, printing=True):    
    # Make sure device is defined
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Move the data and model to the device
    # data_dict = move_data_to_device(data_dict, device)

    # model = model.to(device)

    train_losses = []
    val_losses = []
    
    if printing:
        print("Starting training...")

    for epoch in range(epochs):
        model.train()
        train_loss_temp = 0
        val_loss_temp = 0
        num_batches = 0
        for data_dict in dataloader:
            # Training

            optimizer.zero_grad()

            # Forward pass on the entire graph
            output = model(data_dict['train'])
            mask = data_dict['train']['gini'].mask
            target = data_dict['train']['gini'].y
            
            output_masked = output[mask]
            target_masked = target[mask]

            # Calculate loss using only valid entries
            train_loss = criterion(output_masked, target_masked)

            # Backward pass
            train_loss.backward()
            optimizer.step()
            train_loss_temp += train_loss.item()
            
            num_batches += 1

        # Validation
            model.eval()
            with torch.no_grad():
                output = model(data_dict['val'])
                mask = data_dict['val']['gini'].mask
                target = data_dict['val']['gini'].y
                
                target_masked = target[mask]
                output_masked = output[mask]
                
                val_loss = criterion(output[mask], target[mask])
                val_loss_temp += val_loss.item()
        
        avg_train_loss = train_loss_temp / num_batches
        avg_val_loss = val_loss_temp / num_batches
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        
        if printing:
            print(f'Epoch: {epoch+1}, Training Loss: {train_loss.item():.4f}, Validation Loss: {val_loss.item():.4f}')

        # Early stopping
        early_stopper(val_loss, model)
        if early_stopper.early_stop:
            if printing:
                print(f'Early stopping at epoch {epoch+1} with validation loss {val_loss.item():.4f}')
            break

    # Load the best model weights
    model.load_state_dict(torch.load(early_stopper.path))
    return train_losses, val_losses

# %% [markdown]
# ## Training

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def move_data_dict_to_device(data_dict, device):
    moved = {}
    for k, v in data_dict.items():
        for k2, v2 in v.items():
            if isinstance(v2, Data):
                # Move Data object to device
                v[k2] = v2.to(device)
            elif isinstance(v2, torch.Tensor):
                # Move tensor to device
                v[k2] = v2.to(device)
            else:
                # Leave other types unchanged
                v[k2] = v2
        if hasattr(v, 'to'):
            moved[k] = v.to(device)
        else:
            moved[k] = v
    return moved

data_set = [data_dict[year] for year in data_dict.keys()]

data_set = [move_data_dict_to_device(d, device) for d in data_set]

data_loader = DataLoader(data_set, batch_size=6, shuffle=True)

# %%
next(iter(data_loader))['train']  # Check if DataLoader works
# Out:
# {'political': DataBatch(x=[1158, 9], edge_index=[2, 7534], edge_attr=[7534, 5], country_id=[1158], mask=[1158], batch=[1158], ptr=[7]),
#  'geography': DataBatch(x=[1158, 30], edge_index=[2, 204240], edge_attr=[204240, 16], country_id=[1158], mask=[1158], batch=[1158], ptr=[7]),
#  'culture': DataBatch(x=[1158, 8], edge_index=[2, 47680], edge_attr=[47680, 11], country_id=[1158], mask=[1158], batch=[1158], ptr=[7]),
#  'language': DataBatch(x=[1158, 9], edge_index=[2, 222336], edge_attr=[222336, 2], country_id=[1158], mask=[1158], batch=[1158], ptr=[7]),
#  'economy': DataBatch(x=[1158, 5], edge_index=[2, 153422], edge_attr=[153422, 1], country_id=[1158], mask=[1158], batch=[1158], ptr=[7]),
#  'gini': DataBatch(y=[1158, 1], country_id=[1158], mask=[1158])}

# %%
params = {
    'lr': 0.0007833189943995176,
    'weight_decay': 0.00001558,
    'hidden_size': 50
}


gan_model = MultiModalGNNModel(
    input_dims=network_dimesions, hidden_size=params['hidden_size'], 
    n_gat_layers=2, n_dim_mlp_layers=1, combination_method="concat", mlp_variant="deep")

gan_model = gan_model.to(device)

# criterion for regression task
criterion = nn.L1Loss()

# Fix 7: Better optimizer settings for this problem
optimizer = optim.Adam(gan_model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])  # Lower LR and weight decay

# Initialize early stopping
early_stopper = EarlyStopping(patience=60, min_delta=0.00001, path='model_checkpoints/gan_gini_checkpoint.pt')

# Train the model
epochs = 1000
train_losses_gan, val_losses_gan = train_gnn(epochs, gan_model, optimizer, criterion, data_loader, early_stopper)

# Plot results
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses_gan, label='Training Loss')
plt.plot(val_losses_gan, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Progress')
# Out:
# Removing existing model at: model_checkpoints/gan_gini_checkpoint.pt
# Starting training...
# Epoch: 1, Training Loss: 0.1745, Validation Loss: 0.1297
# Validation loss decreased (0.129661 --> 0.129661).  Saving model ...
# Epoch: 2, Training Loss: 0.0780, Validation Loss: 0.0828
# Validation loss decreased (0.129661 --> 0.082846).  Saving model ...
# Epoch: 3, Training Loss: 0.1006, Validation Loss: 0.1055
# Epoch: 4, Training Loss: 0.1241, Validation Loss: 0.0828
# Epoch: 5, Training Loss: 0.0827, Validation Loss: 0.1093
# Epoch: 6, Training Loss: 0.0584, Validation Loss: 0.1025
# Epoch: 7, Training Loss: 0.0763, Validation Loss: 0.1038
# Epoch: 8, Training Loss: 0.1495, Validation Loss: 0.0604
# Validation loss decreased (0.082846 --> 0.060440).  Saving model ...
# Epoch: 9, Training Loss: 0.1019, Validation Loss: 0.0537
# Validation loss decreased (0.060440 --> 0.053706).  Saving model ...
# Epoch: 10, Training Loss: 0.0765, Validation Loss: 0.0730
# Epoch: 11, Training Loss: 0.0826, Validation Loss: 0.0575
# Epoch: 12, Training Loss: 0.0690, Validation Loss: 0.0567
# Epoch: 13, Training Loss: 0.0775, Validation Loss: 0.0556
# Epoch: 14, Training Loss: 0.0724, Validation Loss: 0.0601
# Epoch: 15, Training Loss: 0.0685, Validation Loss: 0.0523
# Validation loss decreased (0.053706 --> 0.052259).  Saving model ...
# Epoch: 16, Training Loss: 0.0655, Validation Loss: 0.0454
# Validation loss decreased (0.052259 --> 0.045393).  Saving model ...
# Epoch: 17, Training Loss: 0.0529, Validation Loss: 0.0632
# Epoch: 18, Training Loss: 0.0493, Validation Loss: 0.0513
# Epoch: 19, Training Loss: 0.0492, Validation Loss: 0.0507
# Epoch: 20, Training Loss: 0.0491, Validation Loss: 0.0525
# Epoch: 21, Training Loss: 0.0467, Validation Loss: 0.0576
# Epoch: 22, Training Loss: 0.0496, Validation Loss: 0.0498
# Epoch: 23, Training Loss: 0.0573, Validation Loss: 0.0491
# Epoch: 24, Training Loss: 0.0694, Validation Loss: 0.0524
# Epoch: 25, Training Loss: 0.0473, Validation Loss: 0.0461
# Epoch: 26, Training Loss: 0.0506, Validation Loss: 0.0427
# Validation loss decreased (0.045393 --> 0.042716).  Saving model ...
# Epoch: 27, Training Loss: 0.0464, Validation Loss: 0.0419
# Validation loss decreased (0.042716 --> 0.041868).  Saving model ...
# Epoch: 28, Training Loss: 0.0410, Validation Loss: 0.0395
# Validation loss decreased (0.041868 --> 0.039496).  Saving model ...
# Epoch: 29, Training Loss: 0.0420, Validation Loss: 0.0484
# Epoch: 30, Training Loss: 0.0445, Validation Loss: 0.0498
# Epoch: 31, Training Loss: 0.0405, Validation Loss: 0.0381
# Validation loss decreased (0.039496 --> 0.038127).  Saving model ...
# Epoch: 32, Training Loss: 0.0359, Validation Loss: 0.0449
# Epoch: 33, Training Loss: 0.0454, Validation Loss: 0.0451
# Epoch: 34, Training Loss: 0.0350, Validation Loss: 0.0404
# Epoch: 35, Training Loss: 0.0385, Validation Loss: 0.0529
# Epoch: 36, Training Loss: 0.0398, Validation Loss: 0.0518
# Epoch: 37, Training Loss: 0.0391, Validation Loss: 0.0471
# Epoch: 38, Training Loss: 0.0395, Validation Loss: 0.0452
# Epoch: 39, Training Loss: 0.0380, Validation Loss: 0.0524
# Epoch: 40, Training Loss: 0.0388, Validation Loss: 0.0447
# Epoch: 41, Training Loss: 0.0398, Validation Loss: 0.0514
# Epoch: 42, Training Loss: 0.0446, Validation Loss: 0.0477
# Epoch: 43, Training Loss: 0.0582, Validation Loss: 0.0532
# Epoch: 44, Training Loss: 0.0503, Validation Loss: 0.0412
# Epoch: 45, Training Loss: 0.0424, Validation Loss: 0.0446
# Epoch: 46, Training Loss: 0.0376, Validation Loss: 0.0387
# Epoch: 47, Training Loss: 0.0389, Validation Loss: 0.0481
# Epoch: 48, Training Loss: 0.0360, Validation Loss: 0.0343
# Validation loss decreased (0.038127 --> 0.034252).  Saving model ...
# Epoch: 49, Training Loss: 0.0397, Validation Loss: 0.0419
# Epoch: 50, Training Loss: 0.0343, Validation Loss: 0.0351
# Epoch: 51, Training Loss: 0.0356, Validation Loss: 0.0394
# Epoch: 52, Training Loss: 0.0347, Validation Loss: 0.0392
# Epoch: 53, Training Loss: 0.0350, Validation Loss: 0.0338
# Validation loss decreased (0.034252 --> 0.033788).  Saving model ...
# Epoch: 54, Training Loss: 0.0364, Validation Loss: 0.0356
# Epoch: 55, Training Loss: 0.0347, Validation Loss: 0.0419
# Epoch: 56, Training Loss: 0.0324, Validation Loss: 0.0434
# Epoch: 57, Training Loss: 0.0316, Validation Loss: 0.0342
# Epoch: 58, Training Loss: 0.0347, Validation Loss: 0.0380
# Epoch: 59, Training Loss: 0.0331, Validation Loss: 0.0409
# Epoch: 60, Training Loss: 0.0384, Validation Loss: 0.0382
# Epoch: 61, Training Loss: 0.0352, Validation Loss: 0.0431
# Epoch: 62, Training Loss: 0.0349, Validation Loss: 0.0357
# Epoch: 63, Training Loss: 0.0294, Validation Loss: 0.0336
# Validation loss decreased (0.033788 --> 0.033594).  Saving model ...
# Epoch: 64, Training Loss: 0.0328, Validation Loss: 0.0396
# Epoch: 65, Training Loss: 0.0317, Validation Loss: 0.0313
# Validation loss decreased (0.033594 --> 0.031278).  Saving model ...
# Epoch: 66, Training Loss: 0.0297, Validation Loss: 0.0400
# Epoch: 67, Training Loss: 0.0384, Validation Loss: 0.0331
# Epoch: 68, Training Loss: 0.0404, Validation Loss: 0.0397
# Epoch: 69, Training Loss: 0.0278, Validation Loss: 0.0434
# Epoch: 70, Training Loss: 0.0326, Validation Loss: 0.0412
# Epoch: 71, Training Loss: 0.0298, Validation Loss: 0.0390
# Epoch: 72, Training Loss: 0.0282, Validation Loss: 0.0315
# Epoch: 73, Training Loss: 0.0265, Validation Loss: 0.0317
# Epoch: 74, Training Loss: 0.0269, Validation Loss: 0.0307
# Validation loss decreased (0.031278 --> 0.030661).  Saving model ...
# Epoch: 75, Training Loss: 0.0305, Validation Loss: 0.0446
# Epoch: 76, Training Loss: 0.0369, Validation Loss: 0.0360
# Epoch: 77, Training Loss: 0.0338, Validation Loss: 0.0373
# Epoch: 78, Training Loss: 0.0319, Validation Loss: 0.0350
# Epoch: 79, Training Loss: 0.0288, Validation Loss: 0.0368
# Epoch: 80, Training Loss: 0.0311, Validation Loss: 0.0398
# Epoch: 81, Training Loss: 0.0268, Validation Loss: 0.0280
# Validation loss decreased (0.030661 --> 0.028048).  Saving model ...
# Epoch: 82, Training Loss: 0.0275, Validation Loss: 0.0281
# Epoch: 83, Training Loss: 0.0265, Validation Loss: 0.0404
# Epoch: 84, Training Loss: 0.0288, Validation Loss: 0.0256
# Validation loss decreased (0.028048 --> 0.025628).  Saving model ...
# Epoch: 85, Training Loss: 0.0276, Validation Loss: 0.0246
# Validation loss decreased (0.025628 --> 0.024552).  Saving model ...
# Epoch: 86, Training Loss: 0.0302, Validation Loss: 0.0281
# Epoch: 87, Training Loss: 0.0250, Validation Loss: 0.0332
# Epoch: 88, Training Loss: 0.0267, Validation Loss: 0.0303
# Epoch: 89, Training Loss: 0.0252, Validation Loss: 0.0359
# Epoch: 90, Training Loss: 0.0322, Validation Loss: 0.0315
# Epoch: 91, Training Loss: 0.0360, Validation Loss: 0.0393
# Epoch: 92, Training Loss: 0.0329, Validation Loss: 0.0340
# Epoch: 93, Training Loss: 0.0289, Validation Loss: 0.0353
# Epoch: 94, Training Loss: 0.0301, Validation Loss: 0.0268
# Epoch: 95, Training Loss: 0.0285, Validation Loss: 0.0291
# Epoch: 96, Training Loss: 0.0218, Validation Loss: 0.0316
# Epoch: 97, Training Loss: 0.0224, Validation Loss: 0.0273
# Epoch: 98, Training Loss: 0.0245, Validation Loss: 0.0367
# Epoch: 99, Training Loss: 0.0281, Validation Loss: 0.0279
# Epoch: 100, Training Loss: 0.0280, Validation Loss: 0.0256
# Epoch: 101, Training Loss: 0.0252, Validation Loss: 0.0298
# Epoch: 102, Training Loss: 0.0210, Validation Loss: 0.0250
# Epoch: 103, Training Loss: 0.0272, Validation Loss: 0.0260
# Epoch: 104, Training Loss: 0.0219, Validation Loss: 0.0314
# Epoch: 105, Training Loss: 0.0251, Validation Loss: 0.0234
# Validation loss decreased (0.024552 --> 0.023396).  Saving model ...
# Epoch: 106, Training Loss: 0.0218, Validation Loss: 0.0269
# Epoch: 107, Training Loss: 0.0230, Validation Loss: 0.0310
# Epoch: 108, Training Loss: 0.0217, Validation Loss: 0.0234
# Validation loss decreased (0.023396 --> 0.023355).  Saving model ...
# Epoch: 109, Training Loss: 0.0233, Validation Loss: 0.0280
# Epoch: 110, Training Loss: 0.0324, Validation Loss: 0.0216
# Validation loss decreased (0.023355 --> 0.021608).  Saving model ...
# Epoch: 111, Training Loss: 0.0189, Validation Loss: 0.0247
# Epoch: 112, Training Loss: 0.0244, Validation Loss: 0.0255
# Epoch: 113, Training Loss: 0.0221, Validation Loss: 0.0233
# Epoch: 114, Training Loss: 0.0217, Validation Loss: 0.0282
# Epoch: 115, Training Loss: 0.0215, Validation Loss: 0.0251
# Epoch: 116, Training Loss: 0.0235, Validation Loss: 0.0232
# Epoch: 117, Training Loss: 0.0226, Validation Loss: 0.0291
# Epoch: 118, Training Loss: 0.0268, Validation Loss: 0.0215
# Validation loss decreased (0.021608 --> 0.021502).  Saving model ...
# Epoch: 119, Training Loss: 0.0192, Validation Loss: 0.0228
# Epoch: 120, Training Loss: 0.0223, Validation Loss: 0.0275
# Epoch: 121, Training Loss: 0.0192, Validation Loss: 0.0280
# Epoch: 122, Training Loss: 0.0210, Validation Loss: 0.0228
# Epoch: 123, Training Loss: 0.0207, Validation Loss: 0.0356
# Epoch: 124, Training Loss: 0.0314, Validation Loss: 0.0336
# Epoch: 125, Training Loss: 0.0203, Validation Loss: 0.0303
# Epoch: 126, Training Loss: 0.0233, Validation Loss: 0.0374
# Epoch: 127, Training Loss: 0.0282, Validation Loss: 0.0298
# Epoch: 128, Training Loss: 0.0236, Validation Loss: 0.0263
# Epoch: 129, Training Loss: 0.0208, Validation Loss: 0.0299
# Epoch: 130, Training Loss: 0.0190, Validation Loss: 0.0275
# Epoch: 131, Training Loss: 0.0190, Validation Loss: 0.0234
# Epoch: 132, Training Loss: 0.0198, Validation Loss: 0.0215
# Validation loss decreased (0.021502 --> 0.021462).  Saving model ...
# Epoch: 133, Training Loss: 0.0210, Validation Loss: 0.0300
# Epoch: 134, Training Loss: 0.0197, Validation Loss: 0.0288
# Epoch: 135, Training Loss: 0.0213, Validation Loss: 0.0217
# Epoch: 136, Training Loss: 0.0180, Validation Loss: 0.0219
# Epoch: 137, Training Loss: 0.0206, Validation Loss: 0.0267
# Epoch: 138, Training Loss: 0.0205, Validation Loss: 0.0246
# Epoch: 139, Training Loss: 0.0185, Validation Loss: 0.0269
# Epoch: 140, Training Loss: 0.0200, Validation Loss: 0.0264
# Epoch: 141, Training Loss: 0.0261, Validation Loss: 0.0283
# Epoch: 142, Training Loss: 0.0237, Validation Loss: 0.0227
# Epoch: 143, Training Loss: 0.0180, Validation Loss: 0.0307
# Epoch: 144, Training Loss: 0.0230, Validation Loss: 0.0234
# Epoch: 145, Training Loss: 0.0223, Validation Loss: 0.0271
# Epoch: 146, Training Loss: 0.0211, Validation Loss: 0.0226
# Epoch: 147, Training Loss: 0.0187, Validation Loss: 0.0254
# Epoch: 148, Training Loss: 0.0212, Validation Loss: 0.0249
# Epoch: 149, Training Loss: 0.0199, Validation Loss: 0.0252
# Epoch: 150, Training Loss: 0.0176, Validation Loss: 0.0199
# Validation loss decreased (0.021462 --> 0.019894).  Saving model ...
# Epoch: 151, Training Loss: 0.0167, Validation Loss: 0.0291
# Epoch: 152, Training Loss: 0.0163, Validation Loss: 0.0282
# Epoch: 153, Training Loss: 0.0171, Validation Loss: 0.0227
# Epoch: 154, Training Loss: 0.0196, Validation Loss: 0.0187
# Validation loss decreased (0.019894 --> 0.018662).  Saving model ...
# Epoch: 155, Training Loss: 0.0197, Validation Loss: 0.0259
# Epoch: 156, Training Loss: 0.0228, Validation Loss: 0.0261
# Epoch: 157, Training Loss: 0.0184, Validation Loss: 0.0264
# Epoch: 158, Training Loss: 0.0205, Validation Loss: 0.0208
# Epoch: 159, Training Loss: 0.0180, Validation Loss: 0.0226
# Epoch: 160, Training Loss: 0.0181, Validation Loss: 0.0259
# Epoch: 161, Training Loss: 0.0206, Validation Loss: 0.0204
# Epoch: 162, Training Loss: 0.0190, Validation Loss: 0.0247
# Epoch: 163, Training Loss: 0.0249, Validation Loss: 0.0342
# Epoch: 164, Training Loss: 0.0228, Validation Loss: 0.0219
# Epoch: 165, Training Loss: 0.0219, Validation Loss: 0.0274
# Epoch: 166, Training Loss: 0.0215, Validation Loss: 0.0239
# Epoch: 167, Training Loss: 0.0174, Validation Loss: 0.0256
# Epoch: 168, Training Loss: 0.0219, Validation Loss: 0.0226
# Epoch: 169, Training Loss: 0.0191, Validation Loss: 0.0207
# Epoch: 170, Training Loss: 0.0173, Validation Loss: 0.0252
# Epoch: 171, Training Loss: 0.0172, Validation Loss: 0.0263
# Epoch: 172, Training Loss: 0.0207, Validation Loss: 0.0238
# Epoch: 173, Training Loss: 0.0202, Validation Loss: 0.0202
# Epoch: 174, Training Loss: 0.0181, Validation Loss: 0.0217
# Epoch: 175, Training Loss: 0.0167, Validation Loss: 0.0210
# Epoch: 176, Training Loss: 0.0238, Validation Loss: 0.0303
# Epoch: 177, Training Loss: 0.0206, Validation Loss: 0.0269
# Epoch: 178, Training Loss: 0.0215, Validation Loss: 0.0206
# Epoch: 179, Training Loss: 0.0187, Validation Loss: 0.0238
# Epoch: 180, Training Loss: 0.0191, Validation Loss: 0.0237
# Epoch: 181, Training Loss: 0.0180, Validation Loss: 0.0241
# Epoch: 182, Training Loss: 0.0171, Validation Loss: 0.0216
# Epoch: 183, Training Loss: 0.0158, Validation Loss: 0.0226
# Epoch: 184, Training Loss: 0.0171, Validation Loss: 0.0178
# Validation loss decreased (0.018662 --> 0.017839).  Saving model ...
# Epoch: 185, Training Loss: 0.0150, Validation Loss: 0.0220
# Epoch: 186, Training Loss: 0.0164, Validation Loss: 0.0237
# Epoch: 187, Training Loss: 0.0168, Validation Loss: 0.0258
# Epoch: 188, Training Loss: 0.0212, Validation Loss: 0.0212
# Epoch: 189, Training Loss: 0.0161, Validation Loss: 0.0178
# Validation loss decreased (0.017839 --> 0.017807).  Saving model ...
# Epoch: 190, Training Loss: 0.0209, Validation Loss: 0.0274
# Epoch: 191, Training Loss: 0.0176, Validation Loss: 0.0279
# Epoch: 192, Training Loss: 0.0168, Validation Loss: 0.0237
# Epoch: 193, Training Loss: 0.0225, Validation Loss: 0.0263
# Epoch: 194, Training Loss: 0.0170, Validation Loss: 0.0254
# Epoch: 195, Training Loss: 0.0189, Validation Loss: 0.0251
# Epoch: 196, Training Loss: 0.0205, Validation Loss: 0.0241
# Epoch: 197, Training Loss: 0.0196, Validation Loss: 0.0246
# Epoch: 198, Training Loss: 0.0180, Validation Loss: 0.0256
# Epoch: 199, Training Loss: 0.0180, Validation Loss: 0.0194
# Epoch: 200, Training Loss: 0.0164, Validation Loss: 0.0230
# Epoch: 201, Training Loss: 0.0180, Validation Loss: 0.0215
# Epoch: 202, Training Loss: 0.0174, Validation Loss: 0.0263
# Epoch: 203, Training Loss: 0.0173, Validation Loss: 0.0212
# Epoch: 204, Training Loss: 0.0185, Validation Loss: 0.0237
# Epoch: 205, Training Loss: 0.0209, Validation Loss: 0.0216
# Epoch: 206, Training Loss: 0.0198, Validation Loss: 0.0267
# Epoch: 207, Training Loss: 0.0173, Validation Loss: 0.0217
# Epoch: 208, Training Loss: 0.0186, Validation Loss: 0.0243
# Epoch: 209, Training Loss: 0.0161, Validation Loss: 0.0218
# Epoch: 210, Training Loss: 0.0150, Validation Loss: 0.0198
# Epoch: 211, Training Loss: 0.0186, Validation Loss: 0.0227
# Epoch: 212, Training Loss: 0.0213, Validation Loss: 0.0173
# Validation loss decreased (0.017807 --> 0.017272).  Saving model ...
# Epoch: 213, Training Loss: 0.0163, Validation Loss: 0.0217
# Epoch: 214, Training Loss: 0.0159, Validation Loss: 0.0199
# Epoch: 215, Training Loss: 0.0152, Validation Loss: 0.0244
# Epoch: 216, Training Loss: 0.0142, Validation Loss: 0.0226
# Epoch: 217, Training Loss: 0.0193, Validation Loss: 0.0221
# Epoch: 218, Training Loss: 0.0184, Validation Loss: 0.0206
# Epoch: 219, Training Loss: 0.0160, Validation Loss: 0.0203
# Epoch: 220, Training Loss: 0.0149, Validation Loss: 0.0211
# Epoch: 221, Training Loss: 0.0172, Validation Loss: 0.0201
# Epoch: 222, Training Loss: 0.0185, Validation Loss: 0.0175
# Epoch: 223, Training Loss: 0.0169, Validation Loss: 0.0207
# Epoch: 224, Training Loss: 0.0192, Validation Loss: 0.0182
# Epoch: 225, Training Loss: 0.0158, Validation Loss: 0.0226
# Epoch: 226, Training Loss: 0.0180, Validation Loss: 0.0236
# Epoch: 227, Training Loss: 0.0175, Validation Loss: 0.0219
# Epoch: 228, Training Loss: 0.0217, Validation Loss: 0.0220
# Epoch: 229, Training Loss: 0.0160, Validation Loss: 0.0229
# Epoch: 230, Training Loss: 0.0177, Validation Loss: 0.0192
# Epoch: 231, Training Loss: 0.0175, Validation Loss: 0.0306
# Epoch: 232, Training Loss: 0.0220, Validation Loss: 0.0235
# Epoch: 233, Training Loss: 0.0173, Validation Loss: 0.0203
# Epoch: 234, Training Loss: 0.0147, Validation Loss: 0.0200
# Epoch: 235, Training Loss: 0.0154, Validation Loss: 0.0228
# Epoch: 236, Training Loss: 0.0145, Validation Loss: 0.0173
# Epoch: 237, Training Loss: 0.0165, Validation Loss: 0.0152
# Validation loss decreased (0.017272 --> 0.015222).  Saving model ...
# Epoch: 238, Training Loss: 0.0170, Validation Loss: 0.0213
# Epoch: 239, Training Loss: 0.0151, Validation Loss: 0.0208
# Epoch: 240, Training Loss: 0.0158, Validation Loss: 0.0231
# Epoch: 241, Training Loss: 0.0166, Validation Loss: 0.0142
# Validation loss decreased (0.015222 --> 0.014206).  Saving model ...
# Epoch: 242, Training Loss: 0.0208, Validation Loss: 0.0240
# Epoch: 243, Training Loss: 0.0164, Validation Loss: 0.0176
# Epoch: 244, Training Loss: 0.0249, Validation Loss: 0.0209
# Epoch: 245, Training Loss: 0.0156, Validation Loss: 0.0208
# Epoch: 246, Training Loss: 0.0165, Validation Loss: 0.0197
# Epoch: 247, Training Loss: 0.0165, Validation Loss: 0.0206
# Epoch: 248, Training Loss: 0.0141, Validation Loss: 0.0235
# Epoch: 249, Training Loss: 0.0156, Validation Loss: 0.0225
# Epoch: 250, Training Loss: 0.0168, Validation Loss: 0.0206
# Epoch: 251, Training Loss: 0.0132, Validation Loss: 0.0194
# Epoch: 252, Training Loss: 0.0137, Validation Loss: 0.0217
# Epoch: 253, Training Loss: 0.0169, Validation Loss: 0.0180
# Epoch: 254, Training Loss: 0.0229, Validation Loss: 0.0182
# Epoch: 255, Training Loss: 0.0158, Validation Loss: 0.0226
# Epoch: 256, Training Loss: 0.0153, Validation Loss: 0.0222
# Epoch: 257, Training Loss: 0.0191, Validation Loss: 0.0212
# Epoch: 258, Training Loss: 0.0126, Validation Loss: 0.0214
# Epoch: 259, Training Loss: 0.0157, Validation Loss: 0.0175
# Epoch: 260, Training Loss: 0.0147, Validation Loss: 0.0229
# Epoch: 261, Training Loss: 0.0180, Validation Loss: 0.0206
# Epoch: 262, Training Loss: 0.0168, Validation Loss: 0.0185
# Epoch: 263, Training Loss: 0.0167, Validation Loss: 0.0189
# Epoch: 264, Training Loss: 0.0174, Validation Loss: 0.0199
# Epoch: 265, Training Loss: 0.0178, Validation Loss: 0.0174
# Epoch: 266, Training Loss: 0.0176, Validation Loss: 0.0174
# Epoch: 267, Training Loss: 0.0147, Validation Loss: 0.0197
# Epoch: 268, Training Loss: 0.0197, Validation Loss: 0.0239
# Epoch: 269, Training Loss: 0.0228, Validation Loss: 0.0205
# Epoch: 270, Training Loss: 0.0180, Validation Loss: 0.0161
# Epoch: 271, Training Loss: 0.0144, Validation Loss: 0.0183
# Epoch: 272, Training Loss: 0.0121, Validation Loss: 0.0281
# Epoch: 273, Training Loss: 0.0171, Validation Loss: 0.0158
# Epoch: 274, Training Loss: 0.0194, Validation Loss: 0.0169
# Epoch: 275, Training Loss: 0.0147, Validation Loss: 0.0209
# Epoch: 276, Training Loss: 0.0142, Validation Loss: 0.0204
# Epoch: 277, Training Loss: 0.0129, Validation Loss: 0.0199
# Epoch: 278, Training Loss: 0.0130, Validation Loss: 0.0174
# Epoch: 279, Training Loss: 0.0150, Validation Loss: 0.0202
# Epoch: 280, Training Loss: 0.0181, Validation Loss: 0.0205
# Epoch: 281, Training Loss: 0.0152, Validation Loss: 0.0226
# Epoch: 282, Training Loss: 0.0147, Validation Loss: 0.0234
# Epoch: 283, Training Loss: 0.0144, Validation Loss: 0.0206
# Epoch: 284, Training Loss: 0.0182, Validation Loss: 0.0212
# Epoch: 285, Training Loss: 0.0150, Validation Loss: 0.0236
# Epoch: 286, Training Loss: 0.0146, Validation Loss: 0.0193
# Epoch: 287, Training Loss: 0.0126, Validation Loss: 0.0220
# Epoch: 288, Training Loss: 0.0179, Validation Loss: 0.0176
# Epoch: 289, Training Loss: 0.0196, Validation Loss: 0.0231
# Epoch: 290, Training Loss: 0.0163, Validation Loss: 0.0167
# Epoch: 291, Training Loss: 0.0191, Validation Loss: 0.0175
# Epoch: 292, Training Loss: 0.0142, Validation Loss: 0.0204
# Epoch: 293, Training Loss: 0.0148, Validation Loss: 0.0173
# Epoch: 294, Training Loss: 0.0149, Validation Loss: 0.0236
# Epoch: 295, Training Loss: 0.0136, Validation Loss: 0.0216
# Epoch: 296, Training Loss: 0.0167, Validation Loss: 0.0205
# Epoch: 297, Training Loss: 0.0165, Validation Loss: 0.0183
# Epoch: 298, Training Loss: 0.0151, Validation Loss: 0.0165
# Epoch: 299, Training Loss: 0.0125, Validation Loss: 0.0203
# Epoch: 300, Training Loss: 0.0129, Validation Loss: 0.0177
# Epoch: 301, Training Loss: 0.0185, Validation Loss: 0.0200
# Early stopping at epoch 301 with validation loss 0.0200
# Text(0.5, 1.0, 'Training Progress')

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

def evaluate_model(model, dataloader, device, set='test', printing=True):
    model.eval()
    all_true = []
    all_pred = []
    with torch.no_grad():
        for data_dict in dataloader:
            output = model(data_dict[set])
            mask = data_dict[set]['gini'].mask
            true = data_dict[set]['gini'].y[mask==1].cpu().numpy()
            pred = output[mask==1].cpu().numpy()
            all_true.append(true)
            all_pred.append(pred)
    # Concatenate results from all batches
    all_true = np.concatenate(all_true, axis=0)
    all_pred = np.concatenate(all_pred, axis=0)
    
    # Calculate mean percentage error (MPE)
    mape = mean_absolute_percentage_error(all_true,all_pred)
    mae = mean_absolute_error(all_true, all_pred)
    rmse = np.sqrt(mean_squared_error(all_true, all_pred))
    r2 = r2_score(all_true, all_pred)
    
    if printing:

        print(f"Mean Absolute Percentage Error (MAPE): {mape*100:.4f}%")
        print(f"Mean Absolute Error (MAE): {mae:.4f}")
        print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
        print(f"R^2 Score: {r2:.4f}")

        # Visualization: Predicted vs True
        plt.figure(figsize=(6, 5))
        plt.scatter(all_true, all_pred, alpha=0.5)
        plt.plot([all_true.min(), all_true.max()], [all_true.min(), all_true.max()], 'r--', label="Perfect Prediction")
        plt.xlabel('True GINI')
        plt.ylabel('Predicted GINI')
        plt.title('Predicted vs True GINI (Test Set)')
        plt.legend()
        plt.tight_layout()
        plt.show()

        # Visualization: Residuals
        residuals = all_true - all_pred
        plt.figure(figsize=(6, 5))
        plt.hist(residuals, bins=30, alpha=0.7)
        plt.xlabel('Residual (True - Predicted)')
        plt.ylabel('Frequency')
        plt.title('Residuals Distribution')
        plt.tight_layout()
        plt.show()
    
    return all_true, all_pred

# %%
true, pred = evaluate_model(gan_model, data_loader, device, set = 'test')
# Out:
# Mean Absolute Percentage Error (MAPE): 5.7559%
# Mean Absolute Error (MAE): 0.0213
# Root Mean Squared Error (RMSE): 0.0330
# R^2 Score: 0.8496

# %%
def analyze_mlp_weights(model):
    
    first_layer_weights = model.mlp[0].weight 
    
    network_weights = torch.split(first_layer_weights, model.hidden_size, dim=1)
    
    # Compute average absolute weight magnitude for each network
    network_importance = [torch.mean(torch.abs(w)).item() for w in network_weights]
    
    return network_importance

# %%
# relative importance of each network based on weights in the mlp
importance = analyze_mlp_weights(gan_model)
importance
# Out:
# [0.027530156075954437,
#  0.028224043548107147,
#  0.028540197759866714,
#  0.012960068881511688,
#  0.019215678796172142]

# %%
total = sum(importance)
percentages = [(v/total)*100 for v in importance]
percentages
# Out:
# [23.637092631241355,
#  24.23285686918031,
#  24.50430343739084,
#  11.127374207919013,
#  16.498372854268485]

# %% [markdown]
# #### Predicting missing gini data for 2022

# %%
def predict_missing_gini_2022(model, data_dict, df_gini_processed, device):
    """
    Predict Gini values for countries with missing data (exists==0) in 2022 only.
    
    Args:
        model: Trained multimodal GNN model
        data_dict: Dictionary containing the processed data for all years
        df_gini_processed: Processed Gini dataframe with exists column
        device: Computing device (CPU/GPU)
    
    Returns:
        DataFrame with predictions for missing Gini values in 2022
    """
    model.eval()
    predictions = []
    
    year = 2022
    
    with torch.no_grad():
        year_gini = df_gini_processed[df_gini_processed['year'] == year]
        missing_mask = year_gini['exists'] == 0
        
        if missing_mask.sum() == 0:
            print("No missing Gini data found for 2022")
            return pd.DataFrame()
        
        print(f"Found {missing_mask.sum()} countries with missing Gini data in 2022")
        
        year_data = data_dict[year]['test']
        output = model(year_data)
        
        # Extract predictions for countries with missing Gini data
        country_ids = year_data['gini'].country_id.cpu().numpy()
        predictions_array = output.cpu().numpy().flatten()
        
        # Create mapping from country_id to prediction
        country_pred_map = dict(zip(country_ids, predictions_array))
        
        missing_countries = year_gini[missing_mask]['country_id'].values
        
        for country_id in missing_countries:
            if country_id in country_pred_map:
                predictions.append({
                    'year': year,
                    'country_id': country_id,
                    'predicted_gini': country_pred_map[country_id],
                    'original_gini': year_gini[year_gini['country_id'] == country_id]['gini'].iloc[0]
                })
    
    return pd.DataFrame(predictions)

def get_country_names(predictions_df):
    """
    Add country names to the predictions dataframe.
    """
    if len(predictions_df) == 0:
        return predictions_df
    
    # Convert country IDs back to ISO3 codes and then to country names
    country_names = []
    for country_id in predictions_df['country_id']:
        iso3_code = coco.convert(country_id, to='ISO3')
        country_name = coco.convert(iso3_code, to='name_short')
        country_names.append({
            'country_id': country_id,
            'iso3_code': iso3_code,
            'country_name': country_name
        })
    
    country_df = pd.DataFrame(country_names)
    return predictions_df.merge(country_df, on='country_id', how='left')

# Generate predictions for missing Gini values in 2022 only
print("Generating predictions for missing Gini values in 2022...")
missing_gini_predictions_2022 = predict_missing_gini_2022(gan_model, data_dict, df_gini_processed, device)

if len(missing_gini_predictions_2022) > 0:
    # Add country names
    missing_gini_predictions_2022 = get_country_names(missing_gini_predictions_2022)
    
    # Convert predicted Gini back to 0-100 scale (since we normalized to 0-1)
    missing_gini_predictions_2022['predicted_gini_scaled'] = missing_gini_predictions_2022['predicted_gini'] * 100
    
    print(f"Generated {len(missing_gini_predictions_2022)} predictions for missing Gini values in 2022")
    print(f"Countries with missing Gini data in 2022: {missing_gini_predictions_2022['country_name'].nunique()}")
else:
    print("No missing Gini data found for 2022 or no predictions could be generated")

missing_gini_predictions_2022
# Out:
# Generating predictions for missing Gini values in 2022...
# Found 132 countries with missing Gini data in 2022
# Generated 132 predictions for missing Gini values in 2022
# Countries with missing Gini data in 2022: 132
#      year  country_id  predicted_gini  original_gini iso3_code  country_name  \
# 0    2022           4        0.538731            0.0       AFG   Afghanistan
# 1    2022           8        0.313024            0.0       ALB       Albania
# 2    2022          12        0.380258            0.0       DZA       Algeria
# 3    2022          20        0.520753            0.0       AND       Andorra
# 4    2022          24        0.478080            0.0       AGO        Angola
# ..    ...         ...             ...            ...       ...           ...
# 127  2022         834        0.444193            0.0       TZA      Tanzania
# 128  2022         854        0.362000            0.0       BFA  Burkina Faso
# 129  2022         862        0.452322            0.0       VEN     Venezuela
# 130  2022         882        0.866152            0.0       WSM         Samoa
# 131  2022         887        0.353711            0.0       YEM         Yemen
#
#      predicted_gini_scaled
# 0                53.873104
# 1                31.302414
# 2                38.025795
# 3                52.075321
# 4                47.807980
# ..                     ...
# 127              44.419338
# 128              36.200001
# 129              45.232162
# 130              86.615166
# 131              35.371147
#
# [132 rows x 7 columns]

# %%
missing_gini_predictions_2022.to_csv('/home/jovyan/dlss-project/df_missing_gini_pred_with_gini.csv')

# %% [markdown]
# #### Evaluating of specific test countries

# %%
df_gini_2021 = df_gini[df_gini['year'].between(2000, 2022)].reset_index(drop=True)


test_countries = ["FRA", "POL", "SWE", "IND", "IRN", "IDN", 
                  "ZMB", "TCD", "USA", "BRA", "MEX", "BTN", "MLT", "SUR"]
test_countries_numeric = coco.convert(test_countries, to="UNnumeric")

# %%
# Create modified Gini data without 2022 for test countries
def create_evaluation_gini_data(df_gini_original, test_countries):
    """
    Create Gini data excluding 2022 values for specific test countries.
    """
    df_gini_eval = df_gini_original.copy()
    
    # Remove 2022 data for test countries
    mask_to_remove = (df_gini_eval['year'] == 2022) & (df_gini_eval['country'].isin(test_countries))
    df_gini_held_out = df_gini_eval[mask_to_remove].copy()  # Save for evaluation
    df_gini_train = df_gini_eval[~mask_to_remove].reset_index(drop=True)
    
    print(f"Original Gini dataset size: {len(df_gini_original)}")
    print(f"Training Gini dataset size: {len(df_gini_train)} (removed {len(df_gini_held_out)} entries)")
    print(f"Held-out countries for evaluation: {df_gini_held_out['country'].tolist()}")
    
    return df_gini_train, df_gini_held_out

# Create the modified Gini dataset
df_gini_train, df_gini_eval = create_evaluation_gini_data(df_gini, test_countries)
# Out:
# Original Gini dataset size: 4968
# Training Gini dataset size: 4954 (removed 14 entries)
# Held-out countries for evaluation: ['BRA', 'BTN', 'FRA', 'IDN', 'IND', 'IRN', 'MEX', 'MLT', 'POL', 'SUR', 'SWE', 'TCD', 'USA', 'ZMB']

# %%
# Update the create_data_yearly function with the fix
def create_data_yearly_fixed(node_df, edge_df, year, mask_col, year_col='year'):
        
    edge_df_year = edge_df[edge_df[year_col] == year]
    node_df_year = node_df[node_df[year_col] == year].copy()  # copy because we'll potentially modify
    
    # drop duplicate rows in node_df_year
    node_df_year = node_df_year.drop_duplicates(subset=['country_id', year_col], keep='first')
    
    # Get available countries for this year
    available_countries = set(node_df_year['country_id'].values)
    
    # Filter edges to only include countries that exist in nodes for this year
    edge_df_year = edge_df_year[
        edge_df_year['country_id_a'].isin(available_countries) & 
        edge_df_year['country_id_b'].isin(available_countries)
    ]
            
    # --- Edge features ---
    edge_features_cols = [
        col for col in edge_df_year.columns
        if col not in ['country_id_a', 'country_id_b', year_col]
    ]
    edge_features_df = edge_df_year[edge_features_cols].copy()
    
    # Coerce all edge feature columns to numeric, fill NaN with 0
    edge_features_df = edge_features_df.apply(pd.to_numeric, errors='coerce').fillna(0)
    
    # --- Node features ---
    node_features_cols = [
        col for col in node_df_year.columns
        if col not in ['country_id', year_col, mask_col]
    ]
        
    # Ensure node_df_year is sorted by country_id and align features accordingly
    node_df_year_sorted = node_df_year.sort_values(by='country_id').reset_index(drop=True)
        
    # select only feature columns
    node_df_year_features = node_df_year_sorted[node_features_cols].copy()
    
    mask_col_tensor = torch.tensor(node_df_year_sorted[mask_col].values, dtype=torch.float32)
    
    country_id_tensor = torch.tensor(node_df_year_sorted['country_id'].values, dtype=torch.long)
    
    # --- Tensor creation ---
    edge_features_array = edge_features_df.values.astype(np.float32)
    edge_attr = torch.from_numpy(edge_features_array)

    
    node_df_year_features = node_df_year_features.apply(pd.to_numeric, errors='coerce').fillna(0)
    node_features_tensor = torch.tensor(node_df_year_features.values, dtype=torch.float32)
    
    
    # Build a mapping from country_id to its position in the sorted node list
    country_id_to_pos = {cid: i for i, cid in enumerate(node_df_year_sorted['country_id'].values)}
    
    # Map edge indices to positions in the sorted node list
    # since we filtered edges to only include available countries
    edge_index_a = edge_df_year['country_id_a'].map(country_id_to_pos)
    edge_index_b = edge_df_year['country_id_b'].map(country_id_to_pos)
    
    if edge_index_a.isna().any() or edge_index_b.isna().any():
        print(f"Warning: NaN values found in edge mapping for year {year}")
        edge_index_a = edge_index_a.fillna(0)
        edge_index_b = edge_index_b.fillna(0)
    
    edge_index = torch.tensor(
        [edge_index_a.values, edge_index_b.values],
        dtype=torch.long
    )
    
    data = Data(x=node_features_tensor, edge_index=edge_index, edge_attr=edge_attr, country_id=country_id_tensor, mask=mask_col_tensor)
    
    return data

# Update the create_network_data function to use the fixed version
def create_network_data_fixed(node_df, edge_df, gini_df):
    uno_iso3_codes, uno_unnumeric_codes = get_un_countries()
    
    # convert boolean columns to int
    bool_cols_nodes = node_df.select_dtypes(include='bool').columns
    if len(bool_cols_nodes) > 0:
        node_df[bool_cols_nodes] = node_df[bool_cols_nodes].astype(int)
    bool_cols_edges = edge_df.select_dtypes(include='bool').columns
    if len(bool_cols_edges) > 0:
        edge_df[bool_cols_edges] = edge_df[bool_cols_edges].astype(int)
    
    # fill in all missing countries with 0 values for the years from 2000 to 2022
    all_years = range(2000, 2023)
    all_countries = uno_unnumeric_codes
    
    # Create a MultiIndex of all combinations
    full_index = pd.MultiIndex.from_product([all_countries, all_years], names=['country_id', 'year'])
    node_df = node_df.set_index(['country_id', 'year'])
    node_df = node_df.reindex(full_index, fill_value=0).reset_index()
        
    # Fill missing feature columns with 0 (if any NaNs)
    node_features_cols = [col for col in node_df.columns if col not in ['country_id', 'year']]
    node_df[node_features_cols] = node_df[node_features_cols].fillna(0)
    
    edge_feature_cols = [col for col in edge_df.columns if col not in ['country_id_a', 'country_id_b', 'year']]
    
    # merge node_df with gini_df
    node_df_merged = node_df.merge(gini_df, on=['country_id', 'year'])
    
    node_df_merged, edge_df = scale_data(node_df_merged, edge_df, node_features_cols, edge_feature_cols)
    
    # generate train, val and test set.
    # set gini to 0 at respected masks
    
    node_df_train = node_df_merged.copy().drop(columns=['val_mask', 'test_mask'], errors='ignore')
    node_df_val = node_df_merged.copy().drop(columns=['train_mask', 'test_mask'], errors='ignore')
    node_df_test = node_df_merged.copy().drop(columns=['train_mask', 'val_mask'], errors='ignore')
    
    # set gini to 0 where train_mask is 1
    node_df_train.loc[gini_df['train_mask'] == 1, 'gini'] = 0
    node_df_val.loc[gini_df['val_mask'] == 1, 'gini'] = 0
    node_df_test.loc[gini_df['test_mask'] == 1, 'gini'] = 0
    
    
    # limit years from 2000 to 2022
    years = [year for year in range(2000, 2023)]
    
    data_dict = {}
    # create data for each year
    
    for year in years:
        data_train = create_data_yearly_fixed(node_df_train, edge_df, year, 'train_mask', year_col='year')
        data_val = create_data_yearly_fixed(node_df_val, edge_df, year, 'val_mask', year_col='year')
        data_test = create_data_yearly_fixed(node_df_test, edge_df, year, 'test_mask', year_col='year')
        data_dict[year] = {
            'train': data_train,
            'val': data_val,
            'test': data_test
        }
    
    return data_dict

def create_data_fixed(data_combined, gini_df):
    
    # create gini train, val and test masks
    # perform train-val-test split on gini_data for all available values
    
    gini_df = create_global_gini_masks(gini_df, test_size=0.2, val_size=0.2, random_state=42)
    
    data_dict = {}
    
    for modality, data in data_combined.items():
        nodes = data['nodes']
        edges = data['edges']
        data_dict[modality] = create_network_data_fixed(nodes, edges, gini_df)
        
    # add gini data
    gini_data = create_gini_data(gini_df)
    data_dict['gini'] = gini_data
    
    data_dict_reform = {}
    # reform data_dict to have years as keys
    for year in range(2000, 2023):
        data_dict_reform[year] = {
            'political': data_dict['political'][year],
            'geography': data_dict['geography'][year],
            'culture': data_dict['culture'][year],
            'language': data_dict['language'][year],
            'economy': data_dict['economy'][year],
            'gini': gini_data[year]
        }
    
    for year in data_dict_reform.keys():
        data_dict_reform[year] = {
            'train': {
                'political': data_dict_reform[year]['political']['train'],
                'geography': data_dict_reform[year]['geography']['train'],
                'culture': data_dict_reform[year]['culture']['train'],
                'language': data_dict_reform[year]['language']['train'],
                'economy': data_dict_reform[year]['economy']['train'],
                'gini': data_dict_reform[year]['gini']['train']
            },
            'val': {
                'political': data_dict_reform[year]['political']['val'],
                'geography': data_dict_reform[year]['geography']['val'],
                'culture': data_dict_reform[year]['culture']['val'],
                'language': data_dict_reform[year]['language']['val'],
                'economy': data_dict_reform[year]['economy']['val'],
                'gini': data_dict_reform[year]['gini']['val']
            },
            'test': {
                'political': data_dict_reform[year]['political']['test'],
                'geography': data_dict_reform[year]['geography']['test'],
                'culture': data_dict_reform[year]['culture']['test'],
                'language': data_dict_reform[year]['language']['test'],
                'economy': data_dict_reform[year]['economy']['test'],
                'gini': data_dict_reform[year]['gini']['test']
            }
        }
        
    return data_dict_reform

# %%
# Recreate the data pipeline with modified Gini data and fixed function
print("Recreating data pipeline with modified Gini dataset...")

# Process the modified Gini data
df_gini_processed_eval = preprocess_gini(df_gini_train)

# Recreate the entire data structure using the fixed functions
data_dict_eval = create_data_fixed(data_combined, df_gini_processed_eval)

print("Data pipeline recreated successfully!")
print(f"Available years: {sorted(data_dict_eval.keys())}")
# Out:
# Recreating data pipeline with modified Gini dataset...
# Data pipeline recreated successfully!
# Available years: [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
# Prepare evaluation data
data_set_eval = [data_dict_eval[year] for year in data_dict_eval.keys()]
data_set_eval = [move_data_dict_to_device(d, device) for d in data_set_eval]
data_loader_eval = DataLoader(data_set_eval, batch_size=3, shuffle=True)

print(f"Evaluation data prepared with {len(data_set_eval)} years")
# Out:
# Evaluation data prepared with 23 years

# %%
# Train new model on modified dataset
print("Training model on dataset without 2022 data for test countries...")

# model
gan_model_eval = MultiModalGNNModel(
    input_dims=network_dimesions, 
    hidden_size=50,
    n_gat_layers=2,
    n_dim_mlp_layers=1,
    combination_method='concat',
    mlp_variant='deep'
)
gan_model_eval = gan_model_eval.to(device)

# Training setup
criterion_eval = nn.L1Loss()
optimizer_eval = optim.Adam(gan_model_eval.parameters(), lr=0.0007833189943995176, weight_decay=0.00001558)
early_stopper_eval = EarlyStopping(patience=60, min_delta=0.00001, path='model_checkpoints/gan_eval_checkpoint.pt')

# Train the model
epochs = 1000
train_losses_eval, val_losses_eval = train_gnn(epochs, gan_model_eval, optimizer_eval, criterion_eval, data_loader_eval, early_stopper_eval)

# Plot training progress
plt.figure(figsize=(6, 5))
plt.plot(train_losses_eval, label='Training Loss')
plt.plot(val_losses_eval, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Progress')
plt.show()
# Out:
# Training model on dataset without 2022 data for test countries...
# Removing existing model at: model_checkpoints/gan_eval_checkpoint.pt
# Starting training...
# Epoch: 1, Training Loss: 0.0937, Validation Loss: 0.0790
# Validation loss decreased (0.078988 --> 0.078988).  Saving model ...
# Epoch: 2, Training Loss: 0.0709, Validation Loss: 0.0582
# Validation loss decreased (0.078988 --> 0.058222).  Saving model ...
# Epoch: 3, Training Loss: 0.0611, Validation Loss: 0.1121
# Epoch: 4, Training Loss: 0.0749, Validation Loss: 0.0670
# Epoch: 5, Training Loss: 0.0845, Validation Loss: 0.0441
# Validation loss decreased (0.058222 --> 0.044078).  Saving model ...
# Epoch: 6, Training Loss: 0.0604, Validation Loss: 0.0569
# Epoch: 7, Training Loss: 0.0530, Validation Loss: 0.0751
# Epoch: 8, Training Loss: 0.0632, Validation Loss: 0.0697
# Epoch: 9, Training Loss: 0.0589, Validation Loss: 0.0634
# Epoch: 10, Training Loss: 0.0584, Validation Loss: 0.0573
# Epoch: 11, Training Loss: 0.0459, Validation Loss: 0.0564
# Epoch: 12, Training Loss: 0.0433, Validation Loss: 0.0539
# Epoch: 13, Training Loss: 0.0491, Validation Loss: 0.0597
# Epoch: 14, Training Loss: 0.0529, Validation Loss: 0.0462
# Epoch: 15, Training Loss: 0.0416, Validation Loss: 0.0434
# Validation loss decreased (0.044078 --> 0.043410).  Saving model ...
# Epoch: 16, Training Loss: 0.0529, Validation Loss: 0.0358
# Validation loss decreased (0.043410 --> 0.035807).  Saving model ...
# Epoch: 17, Training Loss: 0.0449, Validation Loss: 0.0343
# Validation loss decreased (0.035807 --> 0.034298).  Saving model ...
# Epoch: 18, Training Loss: 0.0379, Validation Loss: 0.0467
# Epoch: 19, Training Loss: 0.0534, Validation Loss: 0.0613
# Epoch: 20, Training Loss: 0.0454, Validation Loss: 0.0535
# Epoch: 21, Training Loss: 0.0408, Validation Loss: 0.0667
# Epoch: 22, Training Loss: 0.0448, Validation Loss: 0.0418
# Epoch: 23, Training Loss: 0.0412, Validation Loss: 0.0424
# Epoch: 24, Training Loss: 0.0364, Validation Loss: 0.0406
# Epoch: 25, Training Loss: 0.0374, Validation Loss: 0.0409
# Epoch: 26, Training Loss: 0.0361, Validation Loss: 0.0428
# Epoch: 27, Training Loss: 0.0429, Validation Loss: 0.0527
# Epoch: 28, Training Loss: 0.0411, Validation Loss: 0.0359
# Epoch: 29, Training Loss: 0.0387, Validation Loss: 0.0416
# Epoch: 30, Training Loss: 0.0341, Validation Loss: 0.0383
# Epoch: 31, Training Loss: 0.0330, Validation Loss: 0.0290
# Validation loss decreased (0.034298 --> 0.028955).  Saving model ...
# Epoch: 32, Training Loss: 0.0338, Validation Loss: 0.0315
# Epoch: 33, Training Loss: 0.0344, Validation Loss: 0.0423
# Epoch: 34, Training Loss: 0.0405, Validation Loss: 0.0303
# Epoch: 35, Training Loss: 0.0532, Validation Loss: 0.0389
# Epoch: 36, Training Loss: 0.0389, Validation Loss: 0.0273
# Validation loss decreased (0.028955 --> 0.027345).  Saving model ...
# Epoch: 37, Training Loss: 0.0327, Validation Loss: 0.0433
# Epoch: 38, Training Loss: 0.0653, Validation Loss: 0.0343
# Epoch: 39, Training Loss: 0.0318, Validation Loss: 0.0445
# Epoch: 40, Training Loss: 0.0307, Validation Loss: 0.0309
# Epoch: 41, Training Loss: 0.0449, Validation Loss: 0.0423
# Epoch: 42, Training Loss: 0.0460, Validation Loss: 0.0384
# Epoch: 43, Training Loss: 0.0403, Validation Loss: 0.0395
# Epoch: 44, Training Loss: 0.0352, Validation Loss: 0.0405
# Epoch: 45, Training Loss: 0.0332, Validation Loss: 0.0335
# Epoch: 46, Training Loss: 0.0357, Validation Loss: 0.0376
# Epoch: 47, Training Loss: 0.0298, Validation Loss: 0.0233
# Validation loss decreased (0.027345 --> 0.023264).  Saving model ...
# Epoch: 48, Training Loss: 0.0321, Validation Loss: 0.0362
# Epoch: 49, Training Loss: 0.0306, Validation Loss: 0.0231
# Validation loss decreased (0.023264 --> 0.023142).  Saving model ...
# Epoch: 50, Training Loss: 0.0311, Validation Loss: 0.0294
# Epoch: 51, Training Loss: 0.0341, Validation Loss: 0.0321
# Epoch: 52, Training Loss: 0.0401, Validation Loss: 0.0298
# Epoch: 53, Training Loss: 0.0328, Validation Loss: 0.0353
# Epoch: 54, Training Loss: 0.0272, Validation Loss: 0.0295
# Epoch: 55, Training Loss: 0.0293, Validation Loss: 0.0279
# Epoch: 56, Training Loss: 0.0336, Validation Loss: 0.0365
# Epoch: 57, Training Loss: 0.0268, Validation Loss: 0.0323
# Epoch: 58, Training Loss: 0.0303, Validation Loss: 0.0379
# Epoch: 59, Training Loss: 0.0280, Validation Loss: 0.0389
# Epoch: 60, Training Loss: 0.0283, Validation Loss: 0.0467
# Epoch: 61, Training Loss: 0.0287, Validation Loss: 0.0392
# Epoch: 62, Training Loss: 0.0315, Validation Loss: 0.0342
# Epoch: 63, Training Loss: 0.0306, Validation Loss: 0.0366
# Epoch: 64, Training Loss: 0.0277, Validation Loss: 0.0340
# Epoch: 65, Training Loss: 0.0330, Validation Loss: 0.0314
# Epoch: 66, Training Loss: 0.0295, Validation Loss: 0.0377
# Epoch: 67, Training Loss: 0.0293, Validation Loss: 0.0398
# Epoch: 68, Training Loss: 0.0271, Validation Loss: 0.0415
# Epoch: 69, Training Loss: 0.0379, Validation Loss: 0.0505
# Epoch: 70, Training Loss: 0.0348, Validation Loss: 0.0330
# Epoch: 71, Training Loss: 0.0377, Validation Loss: 0.0478
# Epoch: 72, Training Loss: 0.0346, Validation Loss: 0.0329
# Epoch: 73, Training Loss: 0.0314, Validation Loss: 0.0363
# Epoch: 74, Training Loss: 0.0289, Validation Loss: 0.0374
# Epoch: 75, Training Loss: 0.0295, Validation Loss: 0.0227
# Validation loss decreased (0.023142 --> 0.022699).  Saving model ...
# Epoch: 76, Training Loss: 0.0284, Validation Loss: 0.0487
# Epoch: 77, Training Loss: 0.0307, Validation Loss: 0.0241
# Epoch: 78, Training Loss: 0.0380, Validation Loss: 0.0213
# Validation loss decreased (0.022699 --> 0.021293).  Saving model ...
# Epoch: 79, Training Loss: 0.0289, Validation Loss: 0.0342
# Epoch: 80, Training Loss: 0.0251, Validation Loss: 0.0315
# Epoch: 81, Training Loss: 0.0278, Validation Loss: 0.0231
# Epoch: 82, Training Loss: 0.0267, Validation Loss: 0.0288
# Epoch: 83, Training Loss: 0.0315, Validation Loss: 0.0348
# Epoch: 84, Training Loss: 0.0278, Validation Loss: 0.0326
# Epoch: 85, Training Loss: 0.0318, Validation Loss: 0.0468
# Epoch: 86, Training Loss: 0.0265, Validation Loss: 0.0309
# Epoch: 87, Training Loss: 0.0315, Validation Loss: 0.0414
# Epoch: 88, Training Loss: 0.0369, Validation Loss: 0.0385
# Epoch: 89, Training Loss: 0.0297, Validation Loss: 0.0313
# Epoch: 90, Training Loss: 0.0304, Validation Loss: 0.0372
# Epoch: 91, Training Loss: 0.0265, Validation Loss: 0.0294
# Epoch: 92, Training Loss: 0.0245, Validation Loss: 0.0304
# Epoch: 93, Training Loss: 0.0254, Validation Loss: 0.0284
# Epoch: 94, Training Loss: 0.0262, Validation Loss: 0.0214
# Epoch: 95, Training Loss: 0.0243, Validation Loss: 0.0398
# Epoch: 96, Training Loss: 0.0268, Validation Loss: 0.0390
# Epoch: 97, Training Loss: 0.0257, Validation Loss: 0.0354
# Epoch: 98, Training Loss: 0.0304, Validation Loss: 0.0293
# Epoch: 99, Training Loss: 0.0323, Validation Loss: 0.0312
# Epoch: 100, Training Loss: 0.0297, Validation Loss: 0.0335
# Epoch: 101, Training Loss: 0.0259, Validation Loss: 0.0221
# Epoch: 102, Training Loss: 0.0303, Validation Loss: 0.0262
# Epoch: 103, Training Loss: 0.0385, Validation Loss: 0.0257
# Epoch: 104, Training Loss: 0.0340, Validation Loss: 0.0247
# Epoch: 105, Training Loss: 0.0319, Validation Loss: 0.0415
# Epoch: 106, Training Loss: 0.0249, Validation Loss: 0.0320
# Epoch: 107, Training Loss: 0.0219, Validation Loss: 0.0237
# Epoch: 108, Training Loss: 0.0259, Validation Loss: 0.0242
# Epoch: 109, Training Loss: 0.0277, Validation Loss: 0.0278
# Epoch: 110, Training Loss: 0.0304, Validation Loss: 0.0239
# Epoch: 111, Training Loss: 0.0221, Validation Loss: 0.0185
# Validation loss decreased (0.021293 --> 0.018513).  Saving model ...
# Epoch: 112, Training Loss: 0.0268, Validation Loss: 0.0409
# Epoch: 113, Training Loss: 0.0221, Validation Loss: 0.0301
# Epoch: 114, Training Loss: 0.0204, Validation Loss: 0.0258
# Epoch: 115, Training Loss: 0.0233, Validation Loss: 0.0197
# Epoch: 116, Training Loss: 0.0216, Validation Loss: 0.0227
# Epoch: 117, Training Loss: 0.0287, Validation Loss: 0.0256
# Epoch: 118, Training Loss: 0.0223, Validation Loss: 0.0286
# Epoch: 119, Training Loss: 0.0202, Validation Loss: 0.0273
# Epoch: 120, Training Loss: 0.0254, Validation Loss: 0.0271
# Epoch: 121, Training Loss: 0.0212, Validation Loss: 0.0267
# Epoch: 122, Training Loss: 0.0232, Validation Loss: 0.0202
# Epoch: 123, Training Loss: 0.0245, Validation Loss: 0.0202
# Epoch: 124, Training Loss: 0.0258, Validation Loss: 0.0286
# Epoch: 125, Training Loss: 0.0220, Validation Loss: 0.0265
# Epoch: 126, Training Loss: 0.0205, Validation Loss: 0.0208
# Epoch: 127, Training Loss: 0.0262, Validation Loss: 0.0218
# Epoch: 128, Training Loss: 0.0255, Validation Loss: 0.0224
# Epoch: 129, Training Loss: 0.0228, Validation Loss: 0.0235
# Epoch: 130, Training Loss: 0.0328, Validation Loss: 0.0211
# Epoch: 131, Training Loss: 0.0246, Validation Loss: 0.0246
# Epoch: 132, Training Loss: 0.0185, Validation Loss: 0.0198
# Epoch: 133, Training Loss: 0.0226, Validation Loss: 0.0271
# Epoch: 134, Training Loss: 0.0186, Validation Loss: 0.0291
# Epoch: 135, Training Loss: 0.0212, Validation Loss: 0.0241
# Epoch: 136, Training Loss: 0.0246, Validation Loss: 0.0211
# Epoch: 137, Training Loss: 0.0233, Validation Loss: 0.0222
# Epoch: 138, Training Loss: 0.0203, Validation Loss: 0.0273
# Epoch: 139, Training Loss: 0.0217, Validation Loss: 0.0224
# Epoch: 140, Training Loss: 0.0201, Validation Loss: 0.0163
# Validation loss decreased (0.018513 --> 0.016338).  Saving model ...
# Epoch: 141, Training Loss: 0.0206, Validation Loss: 0.0169
# Epoch: 142, Training Loss: 0.0260, Validation Loss: 0.0238
# Epoch: 143, Training Loss: 0.0213, Validation Loss: 0.0157
# Validation loss decreased (0.016338 --> 0.015661).  Saving model ...
# Epoch: 144, Training Loss: 0.0211, Validation Loss: 0.0169
# Epoch: 145, Training Loss: 0.0233, Validation Loss: 0.0423
# Epoch: 146, Training Loss: 0.0253, Validation Loss: 0.0265
# Epoch: 147, Training Loss: 0.0214, Validation Loss: 0.0319
# Epoch: 148, Training Loss: 0.0222, Validation Loss: 0.0263
# Epoch: 149, Training Loss: 0.0185, Validation Loss: 0.0202
# Epoch: 150, Training Loss: 0.0188, Validation Loss: 0.0292
# Epoch: 151, Training Loss: 0.0219, Validation Loss: 0.0283
# Epoch: 152, Training Loss: 0.0246, Validation Loss: 0.0299
# Epoch: 153, Training Loss: 0.0165, Validation Loss: 0.0228
# Epoch: 154, Training Loss: 0.0211, Validation Loss: 0.0180
# Epoch: 155, Training Loss: 0.0211, Validation Loss: 0.0254
# Epoch: 156, Training Loss: 0.0202, Validation Loss: 0.0259
# Epoch: 157, Training Loss: 0.0174, Validation Loss: 0.0331
# Epoch: 158, Training Loss: 0.0167, Validation Loss: 0.0207
# Epoch: 159, Training Loss: 0.0262, Validation Loss: 0.0437
# Epoch: 160, Training Loss: 0.0224, Validation Loss: 0.0277
# Epoch: 161, Training Loss: 0.0180, Validation Loss: 0.0193
# Epoch: 162, Training Loss: 0.0361, Validation Loss: 0.0241
# Epoch: 163, Training Loss: 0.0208, Validation Loss: 0.0244
# Epoch: 164, Training Loss: 0.0199, Validation Loss: 0.0189
# Epoch: 165, Training Loss: 0.0202, Validation Loss: 0.0245
# Epoch: 166, Training Loss: 0.0260, Validation Loss: 0.0322
# Epoch: 167, Training Loss: 0.0237, Validation Loss: 0.0444
# Epoch: 168, Training Loss: 0.0221, Validation Loss: 0.0200
# Epoch: 169, Training Loss: 0.0186, Validation Loss: 0.0205
# Epoch: 170, Training Loss: 0.0210, Validation Loss: 0.0256
# Epoch: 171, Training Loss: 0.0202, Validation Loss: 0.0197
# Epoch: 172, Training Loss: 0.0286, Validation Loss: 0.0177
# Epoch: 173, Training Loss: 0.0230, Validation Loss: 0.0216
# Epoch: 174, Training Loss: 0.0169, Validation Loss: 0.0173
# Epoch: 175, Training Loss: 0.0222, Validation Loss: 0.0277
# Epoch: 176, Training Loss: 0.0176, Validation Loss: 0.0187
# Epoch: 177, Training Loss: 0.0195, Validation Loss: 0.0231
# Epoch: 178, Training Loss: 0.0180, Validation Loss: 0.0300
# Epoch: 179, Training Loss: 0.0194, Validation Loss: 0.0253
# Epoch: 180, Training Loss: 0.0190, Validation Loss: 0.0234
# Epoch: 181, Training Loss: 0.0176, Validation Loss: 0.0210
# Epoch: 182, Training Loss: 0.0173, Validation Loss: 0.0241
# Epoch: 183, Training Loss: 0.0181, Validation Loss: 0.0255
# Epoch: 184, Training Loss: 0.0197, Validation Loss: 0.0191
# Epoch: 185, Training Loss: 0.0200, Validation Loss: 0.0273
# Epoch: 186, Training Loss: 0.0175, Validation Loss: 0.0310
# Epoch: 187, Training Loss: 0.0171, Validation Loss: 0.0174
# Epoch: 188, Training Loss: 0.0172, Validation Loss: 0.0224
# Epoch: 189, Training Loss: 0.0207, Validation Loss: 0.0157
# Epoch: 190, Training Loss: 0.0181, Validation Loss: 0.0149
# Validation loss decreased (0.015661 --> 0.014854).  Saving model ...
# Epoch: 191, Training Loss: 0.0126, Validation Loss: 0.0216
# Epoch: 192, Training Loss: 0.0196, Validation Loss: 0.0383
# Epoch: 193, Training Loss: 0.0169, Validation Loss: 0.0300
# Epoch: 194, Training Loss: 0.0192, Validation Loss: 0.0497
# Epoch: 195, Training Loss: 0.0196, Validation Loss: 0.0150
# Epoch: 196, Training Loss: 0.0183, Validation Loss: 0.0304
# Epoch: 197, Training Loss: 0.0177, Validation Loss: 0.0249
# Epoch: 198, Training Loss: 0.0147, Validation Loss: 0.0297
# Epoch: 199, Training Loss: 0.0197, Validation Loss: 0.0196
# Epoch: 200, Training Loss: 0.0181, Validation Loss: 0.0202
# Epoch: 201, Training Loss: 0.0183, Validation Loss: 0.0132
# Validation loss decreased (0.014854 --> 0.013162).  Saving model ...
# Epoch: 202, Training Loss: 0.0205, Validation Loss: 0.0253
# Epoch: 203, Training Loss: 0.0155, Validation Loss: 0.0280
# Epoch: 204, Training Loss: 0.0130, Validation Loss: 0.0175
# Epoch: 205, Training Loss: 0.0211, Validation Loss: 0.0345
# Epoch: 206, Training Loss: 0.0148, Validation Loss: 0.0255
# Epoch: 207, Training Loss: 0.0188, Validation Loss: 0.0228
# Epoch: 208, Training Loss: 0.0197, Validation Loss: 0.0269
# Epoch: 209, Training Loss: 0.0140, Validation Loss: 0.0157
# Epoch: 210, Training Loss: 0.0131, Validation Loss: 0.0299
# Epoch: 211, Training Loss: 0.0167, Validation Loss: 0.0196
# Epoch: 212, Training Loss: 0.0158, Validation Loss: 0.0193
# Epoch: 213, Training Loss: 0.0188, Validation Loss: 0.0211
# Epoch: 214, Training Loss: 0.0245, Validation Loss: 0.0327
# Epoch: 215, Training Loss: 0.0176, Validation Loss: 0.0311
# Epoch: 216, Training Loss: 0.0172, Validation Loss: 0.0159
# Epoch: 217, Training Loss: 0.0151, Validation Loss: 0.0279
# Epoch: 218, Training Loss: 0.0169, Validation Loss: 0.0441
# Epoch: 219, Training Loss: 0.0172, Validation Loss: 0.0151
# Epoch: 220, Training Loss: 0.0144, Validation Loss: 0.0254
# Epoch: 221, Training Loss: 0.0173, Validation Loss: 0.0195
# Epoch: 222, Training Loss: 0.0203, Validation Loss: 0.0426
# Epoch: 223, Training Loss: 0.0156, Validation Loss: 0.0199
# Epoch: 224, Training Loss: 0.0166, Validation Loss: 0.0250
# Epoch: 225, Training Loss: 0.0158, Validation Loss: 0.0247
# Epoch: 226, Training Loss: 0.0160, Validation Loss: 0.0297
# Epoch: 227, Training Loss: 0.0129, Validation Loss: 0.0330
# Epoch: 228, Training Loss: 0.0187, Validation Loss: 0.0249
# Epoch: 229, Training Loss: 0.0166, Validation Loss: 0.0251
# Epoch: 230, Training Loss: 0.0126, Validation Loss: 0.0366
# Epoch: 231, Training Loss: 0.0143, Validation Loss: 0.0383
# Epoch: 232, Training Loss: 0.0125, Validation Loss: 0.0135
# Epoch: 233, Training Loss: 0.0153, Validation Loss: 0.0183
# Epoch: 234, Training Loss: 0.0206, Validation Loss: 0.0291
# Epoch: 235, Training Loss: 0.0182, Validation Loss: 0.0123
# Validation loss decreased (0.013162 --> 0.012275).  Saving model ...
# Epoch: 236, Training Loss: 0.0187, Validation Loss: 0.0165
# Epoch: 237, Training Loss: 0.0180, Validation Loss: 0.0274
# Epoch: 238, Training Loss: 0.0170, Validation Loss: 0.0187
# Epoch: 239, Training Loss: 0.0196, Validation Loss: 0.0250
# Epoch: 240, Training Loss: 0.0214, Validation Loss: 0.0389
# Epoch: 241, Training Loss: 0.0154, Validation Loss: 0.0256
# Epoch: 242, Training Loss: 0.0116, Validation Loss: 0.0186
# Epoch: 243, Training Loss: 0.0133, Validation Loss: 0.0234
# Epoch: 244, Training Loss: 0.0190, Validation Loss: 0.0267
# Epoch: 245, Training Loss: 0.0164, Validation Loss: 0.0298
# Epoch: 246, Training Loss: 0.0183, Validation Loss: 0.0157
# Epoch: 247, Training Loss: 0.0181, Validation Loss: 0.0349
# Epoch: 248, Training Loss: 0.0156, Validation Loss: 0.0133
# Epoch: 249, Training Loss: 0.0165, Validation Loss: 0.0143
# Epoch: 250, Training Loss: 0.0160, Validation Loss: 0.0277
# Epoch: 251, Training Loss: 0.0162, Validation Loss: 0.0361
# Epoch: 252, Training Loss: 0.0169, Validation Loss: 0.0166
# Epoch: 253, Training Loss: 0.0140, Validation Loss: 0.0146
# Epoch: 254, Training Loss: 0.0170, Validation Loss: 0.0316
# Epoch: 255, Training Loss: 0.0305, Validation Loss: 0.0133
# Epoch: 256, Training Loss: 0.0230, Validation Loss: 0.0313
# Epoch: 257, Training Loss: 0.0152, Validation Loss: 0.0345
# Epoch: 258, Training Loss: 0.0203, Validation Loss: 0.0158
# Epoch: 259, Training Loss: 0.0244, Validation Loss: 0.0234
# Epoch: 260, Training Loss: 0.0195, Validation Loss: 0.0226
# Epoch: 261, Training Loss: 0.0177, Validation Loss: 0.0258
# Epoch: 262, Training Loss: 0.0178, Validation Loss: 0.0138
# Epoch: 263, Training Loss: 0.0171, Validation Loss: 0.0204
# Epoch: 264, Training Loss: 0.0158, Validation Loss: 0.0204
# Epoch: 265, Training Loss: 0.0201, Validation Loss: 0.0166
# Epoch: 266, Training Loss: 0.0178, Validation Loss: 0.0219
# Epoch: 267, Training Loss: 0.0132, Validation Loss: 0.0173
# Epoch: 268, Training Loss: 0.0165, Validation Loss: 0.0298
# Epoch: 269, Training Loss: 0.0206, Validation Loss: 0.0238
# Epoch: 270, Training Loss: 0.0285, Validation Loss: 0.0189
# Epoch: 271, Training Loss: 0.0153, Validation Loss: 0.0187
# Epoch: 272, Training Loss: 0.0226, Validation Loss: 0.0330
# Epoch: 273, Training Loss: 0.0171, Validation Loss: 0.0243
# Epoch: 274, Training Loss: 0.0150, Validation Loss: 0.0300
# Epoch: 275, Training Loss: 0.0120, Validation Loss: 0.0232
# Epoch: 276, Training Loss: 0.0166, Validation Loss: 0.0200
# Epoch: 277, Training Loss: 0.0123, Validation Loss: 0.0142
# Epoch: 278, Training Loss: 0.0189, Validation Loss: 0.0258
# Epoch: 279, Training Loss: 0.0262, Validation Loss: 0.0214
# Epoch: 280, Training Loss: 0.0211, Validation Loss: 0.0203
# Epoch: 281, Training Loss: 0.0165, Validation Loss: 0.0149
# Epoch: 282, Training Loss: 0.0166, Validation Loss: 0.0222
# Epoch: 283, Training Loss: 0.0140, Validation Loss: 0.0160
# Epoch: 284, Training Loss: 0.0152, Validation Loss: 0.0276
# Epoch: 285, Training Loss: 0.0120, Validation Loss: 0.0306
# Epoch: 286, Training Loss: 0.0162, Validation Loss: 0.0246
# Epoch: 287, Training Loss: 0.0154, Validation Loss: 0.0279
# Epoch: 288, Training Loss: 0.0157, Validation Loss: 0.0307
# Epoch: 289, Training Loss: 0.0164, Validation Loss: 0.0147
# Epoch: 290, Training Loss: 0.0142, Validation Loss: 0.0207
# Epoch: 291, Training Loss: 0.0142, Validation Loss: 0.0158
# Epoch: 292, Training Loss: 0.0155, Validation Loss: 0.0284
# Epoch: 293, Training Loss: 0.0137, Validation Loss: 0.0364
# Epoch: 294, Training Loss: 0.0187, Validation Loss: 0.0115
# Validation loss decreased (0.012275 --> 0.011547).  Saving model ...
# Epoch: 295, Training Loss: 0.0184, Validation Loss: 0.0191
# Epoch: 296, Training Loss: 0.0122, Validation Loss: 0.0162
# Epoch: 297, Training Loss: 0.0142, Validation Loss: 0.0141
# Epoch: 298, Training Loss: 0.0218, Validation Loss: 0.0243
# Epoch: 299, Training Loss: 0.0172, Validation Loss: 0.0178
# Epoch: 300, Training Loss: 0.0208, Validation Loss: 0.0182
# Epoch: 301, Training Loss: 0.0168, Validation Loss: 0.0121
# Epoch: 302, Training Loss: 0.0151, Validation Loss: 0.0258
# Epoch: 303, Training Loss: 0.0158, Validation Loss: 0.0252
# Epoch: 304, Training Loss: 0.0134, Validation Loss: 0.0174
# Epoch: 305, Training Loss: 0.0202, Validation Loss: 0.0253
# Epoch: 306, Training Loss: 0.0180, Validation Loss: 0.0321
# Epoch: 307, Training Loss: 0.0155, Validation Loss: 0.0194
# Epoch: 308, Training Loss: 0.0136, Validation Loss: 0.0149
# Epoch: 309, Training Loss: 0.0207, Validation Loss: 0.0370
# Epoch: 310, Training Loss: 0.0128, Validation Loss: 0.0298
# Epoch: 311, Training Loss: 0.0146, Validation Loss: 0.0129
# Epoch: 312, Training Loss: 0.0138, Validation Loss: 0.0205
# Epoch: 313, Training Loss: 0.0148, Validation Loss: 0.0107
# Validation loss decreased (0.011547 --> 0.010670).  Saving model ...
# Epoch: 314, Training Loss: 0.0160, Validation Loss: 0.0173
# Epoch: 315, Training Loss: 0.0172, Validation Loss: 0.0214
# Epoch: 316, Training Loss: 0.0235, Validation Loss: 0.0236
# Epoch: 317, Training Loss: 0.0171, Validation Loss: 0.0370
# Epoch: 318, Training Loss: 0.0148, Validation Loss: 0.0301
# Epoch: 319, Training Loss: 0.0168, Validation Loss: 0.0265
# Epoch: 320, Training Loss: 0.0197, Validation Loss: 0.0202
# Epoch: 321, Training Loss: 0.0152, Validation Loss: 0.0183
# Epoch: 322, Training Loss: 0.0192, Validation Loss: 0.0208
# Epoch: 323, Training Loss: 0.0155, Validation Loss: 0.0237
# Epoch: 324, Training Loss: 0.0185, Validation Loss: 0.0193
# Epoch: 325, Training Loss: 0.0141, Validation Loss: 0.0320
# Epoch: 326, Training Loss: 0.0153, Validation Loss: 0.0208
# Epoch: 327, Training Loss: 0.0217, Validation Loss: 0.0203
# Epoch: 328, Training Loss: 0.0216, Validation Loss: 0.0216
# Epoch: 329, Training Loss: 0.0179, Validation Loss: 0.0255
# Epoch: 330, Training Loss: 0.0152, Validation Loss: 0.0229
# Epoch: 331, Training Loss: 0.0172, Validation Loss: 0.0228
# Epoch: 332, Training Loss: 0.0163, Validation Loss: 0.0120
# Epoch: 333, Training Loss: 0.0134, Validation Loss: 0.0227
# Epoch: 334, Training Loss: 0.0116, Validation Loss: 0.0206
# Epoch: 335, Training Loss: 0.0192, Validation Loss: 0.0254
# Epoch: 336, Training Loss: 0.0150, Validation Loss: 0.0201
# Epoch: 337, Training Loss: 0.0116, Validation Loss: 0.0184
# Epoch: 338, Training Loss: 0.0149, Validation Loss: 0.0136
# Epoch: 339, Training Loss: 0.0162, Validation Loss: 0.0275
# Epoch: 340, Training Loss: 0.0209, Validation Loss: 0.0230
# Epoch: 341, Training Loss: 0.0128, Validation Loss: 0.0193
# Epoch: 342, Training Loss: 0.0120, Validation Loss: 0.0257
# Epoch: 343, Training Loss: 0.0126, Validation Loss: 0.0158
# Epoch: 344, Training Loss: 0.0202, Validation Loss: 0.0263
# Epoch: 345, Training Loss: 0.0174, Validation Loss: 0.0179
# Epoch: 346, Training Loss: 0.0174, Validation Loss: 0.0181
# Epoch: 347, Training Loss: 0.0128, Validation Loss: 0.0185
# Epoch: 348, Training Loss: 0.0181, Validation Loss: 0.0130
# Epoch: 349, Training Loss: 0.0207, Validation Loss: 0.0320
# Epoch: 350, Training Loss: 0.0167, Validation Loss: 0.0150
# Epoch: 351, Training Loss: 0.0118, Validation Loss: 0.0150
# Epoch: 352, Training Loss: 0.0110, Validation Loss: 0.0184
# Epoch: 353, Training Loss: 0.0143, Validation Loss: 0.0326
# Epoch: 354, Training Loss: 0.0142, Validation Loss: 0.0189
# Epoch: 355, Training Loss: 0.0147, Validation Loss: 0.0214
# Epoch: 356, Training Loss: 0.0153, Validation Loss: 0.0304
# Epoch: 357, Training Loss: 0.0185, Validation Loss: 0.0184
# Epoch: 358, Training Loss: 0.0198, Validation Loss: 0.0203
# Epoch: 359, Training Loss: 0.0120, Validation Loss: 0.0215
# Epoch: 360, Training Loss: 0.0129, Validation Loss: 0.0251
# Epoch: 361, Training Loss: 0.0189, Validation Loss: 0.0172
# Epoch: 362, Training Loss: 0.0182, Validation Loss: 0.0216
# Epoch: 363, Training Loss: 0.0140, Validation Loss: 0.0202
# Epoch: 364, Training Loss: 0.0131, Validation Loss: 0.0140
# Epoch: 365, Training Loss: 0.0185, Validation Loss: 0.0208
# Epoch: 366, Training Loss: 0.0181, Validation Loss: 0.0138
# Epoch: 367, Training Loss: 0.0159, Validation Loss: 0.0198
# Epoch: 368, Training Loss: 0.0175, Validation Loss: 0.0186
# Epoch: 369, Training Loss: 0.0147, Validation Loss: 0.0203
# Epoch: 370, Training Loss: 0.0175, Validation Loss: 0.0238
# Epoch: 371, Training Loss: 0.0243, Validation Loss: 0.0216
# Epoch: 372, Training Loss: 0.0119, Validation Loss: 0.0246
# Epoch: 373, Training Loss: 0.0136, Validation Loss: 0.0218
# Early stopping at epoch 373 with validation loss 0.0218

# %%
# Predict for test countries in 2022 with visualization
def predict_test_countries_2022(model, data_dict_original, df_gini_eval, test_countries, device):
    """
    Predict Gini values for test countries in 2022 using original data structure.
    """
    model.eval()
    predictions = []
    
    year = 2022
    
    if year not in data_dict_original:
        print(f"Year {year} not available in original data")
        return pd.DataFrame()
    
    with torch.no_grad():
        year_data = data_dict_original[year]['test']  # Use test split
        
        # Get model predictions for all countries
        output = model(year_data)
        
        # Extract country IDs and predictions
        country_ids = year_data['gini'].country_id.cpu().numpy()
        predictions_array = output.cpu().numpy().flatten()
        
        # Create mapping from country_id to prediction
        country_pred_map = dict(zip(country_ids, predictions_array))
        
        # Get predictions for test countries
        for country in test_countries:
            country_id = convert_country_code(country, 'UNnumeric')
            if country_id is not None and country_id in country_pred_map:
                # Get actual Gini value from held-out data
                actual_row = df_gini_eval[df_gini_eval['country'] == country]
                if len(actual_row) > 0:
                    actual_gini = actual_row['gini'].iloc[0]
                    
                    predictions.append({
                        'country': country,
                        'country_id': country_id,
                        'predicted_gini_normalized': country_pred_map[country_id],
                        'actual_gini_original': actual_gini,
                        'predicted_gini_scaled': country_pred_map[country_id],
                        'actual_gini_normalized': actual_gini / 100
                    })
                else:
                    print(f"Warning: No actual 2022 Gini data found for {country}")
    
    return pd.DataFrame(predictions)

# Make predictions using original data structure (which includes test countries for 2022)
print("Generating predictions for test countries in 2022...")
evaluation_results = predict_test_countries_2022(
    gan_model_eval, data_dict, df_gini_eval, test_countries, device
)

print(f"Generated predictions for {len(evaluation_results)} countries")
if len(evaluation_results) > 0:
    print("Test countries with predictions:")
    for _, row in evaluation_results.iterrows():
        print(f"  {row['country']}: Actual={row['actual_gini_original']:.2f}, Predicted={row['predicted_gini_scaled']:.2f}")
    
    # Create visualization with true vs predicted values
    plt.figure(figsize=(6, 5))
    
    # Extract values for plotting
    true_values = evaluation_results['actual_gini_normalized'].values
    pred_values = evaluation_results['predicted_gini_scaled'].values
    country_labels = evaluation_results['country'].values
    
    # Create scatter plot
    plt.scatter(true_values, pred_values, alpha=0.7)
    
    # Add country labels to points
    for i, country in enumerate(country_labels):
        plt.annotate(country, (true_values[i], pred_values[i]), 
                    xytext=(5, 5), textcoords='offset points', 
                    fontsize=9, alpha=0.8)
    
    # Add perfect fit line (y=x)
    min_val = min(min(true_values), min(pred_values))
    max_val = max(max(true_values), max(pred_values))
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', alpha=0.8, label="Perfect Prediction")
    
    # Calculate and display metrics
    mae = np.mean(np.abs(true_values - pred_values))
    rmse = np.sqrt(np.mean((true_values - pred_values) ** 2))
    mape = np.mean(np.abs((true_values - pred_values) / true_values)) * 100
    
    # Customize plot
    plt.xlabel('True Gini')
    plt.ylabel('Predicted Gini')
    plt.title('True vs Predicted Gini Coefficients for Test Countries (2022)')
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    # Print detailed results
    print("\nDetailed Results:")
    print(f"Mean Absolute Error: {mae:.2f}")
    print(f"Root Mean Square Error: {rmse:.2f}")
    print(f"Mean Absolute Percentage Error: {mape:.1f}%")
# Out:
# Generating predictions for test countries in 2022...
# Generated predictions for 14 countries
# Test countries with predictions:
#   FRA: Actual=31.20, Predicted=0.32
#   POL: Actual=28.90, Predicted=0.31
#   SWE: Actual=31.60, Predicted=0.27
#   IND: Actual=25.50, Predicted=0.34
#   IRN: Actual=34.80, Predicted=0.33
#   IDN: Actual=35.50, Predicted=0.36
#   ZMB: Actual=51.50, Predicted=0.49
#   TCD: Actual=37.40, Predicted=0.44
#   USA: Actual=41.70, Predicted=0.41
#   BRA: Actual=52.00, Predicted=0.52
#   MEX: Actual=43.50, Predicted=0.48
#   BTN: Actual=28.50, Predicted=0.38
#   MLT: Actual=34.60, Predicted=0.30
#   SUR: Actual=39.20, Predicted=0.50
# Detailed Results:
# Mean Absolute Error: 0.04
# Root Mean Square Error: 0.05
# Mean Absolute Percentage Error: 12.2%

# %% [markdown]
# ## Optuna Optimization

# %%
import optuna

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def move_data_dict_to_device(data_dict, device):
    moved = {}
    for k, v in data_dict.items():
        for k2, v2 in v.items():
            if isinstance(v2, Data):
                # Move Data object to device
                v[k2] = v2.to(device)
            elif isinstance(v2, torch.Tensor):
                # Move tensor to device
                v[k2] = v2.to(device)
            else:
                # Leave other types unchanged
                v[k2] = v2
        if hasattr(v, 'to'):
            moved[k] = v.to(device)
        else:
            moved[k] = v
    return moved

data_set = [data_dict[year] for year in data_dict.keys()]

data_set = [move_data_dict_to_device(d, device) for d in data_set]

def objective(trial):
    
    # set hyperparameters
    hidden_size = trial.suggest_int("hidden_size", 20, 300, step=16)
    weight_decay = trial.suggest_float("weight_decay", 1e-7, 1e-3, log=True)
    lr = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    
    n_gat_layers = trial.suggest_int("n_gat_layers", 1, 3)
    n_dim_mlp_layers = trial.suggest_int("n_dim_mlp_layers", 0, 3)
    combination_method = trial.suggest_categorical("combination_method", ['concat', 'attention'])
    batch_size = trial.suggest_int("batch_size", 2, 8, step=1)
    
    mlp_variant = trial.suggest_categorical("mlp_variant", ['default', 'deep', 'shallow'])
    
    # prepare training
    data_loader = DataLoader(data_set, batch_size=batch_size, shuffle=True)
    
    gan_model = MultiModalGNNModel(
        input_dims=network_dimesions, hidden_size=hidden_size,
        n_gat_layers=n_gat_layers, n_dim_mlp_layers=n_dim_mlp_layers,
        combination_method=combination_method,
        mlp_variant=mlp_variant)
    
    gan_model = gan_model.to(device)
    
    # criterion for regression task
    criterion = nn.L1Loss()
    
    # Fix 7: Better optimizer settings for this problem
    optimizer = optim.Adam(gan_model.parameters(), lr=lr, weight_decay=weight_decay)  # Lower LR and weight decay
    
    # Initialize early stopping
    early_stopper = EarlyStopping(patience=50, min_delta=0.00001, path='model_checkpoints/gan_gini_checkpoint_optuna.pt', printing=False)
    
    # Train the model
    epochs = 1000
    train_losses_gan, val_losses_gan = train_gnn(epochs, gan_model, optimizer, criterion, data_loader, early_stopper, printing = False)
    
    # Evaluate the model on the validation set
    true, pred = evaluate_model(gan_model, data_loader, device, set='val', printing =False)
    mae = mean_absolute_error(true, pred)
    
    return mae

study = optuna.create_study(
    study_name = "Multimodal_with_Gini",
    storage="sqlite:///optuna_with_gini_study.db",
    direction="minimize", 
    load_if_exists=True)
# study.optimize(objective, n_trials=50) # use when running new trials

print("Best trial:")
print(study.best_trial.params)
# Out:
# [I 2025-08-27 15:45:39,593] Using an existing study with name 'Multimodal_with_Gini' instead of creating a new one.
# Best trial:
# {'hidden_size': 50, 'weight_decay': 1.5579380006082785e-05, 'lr': 0.0007833189943995176, 'n_gat_layers': 2, 'n_mlp_layers': 1, 'combination_method': 'concat', 'batch_size': 6, 'mlp_variant': 'deep'}
