# %% [markdown]
# # Multimodal Network
#
# Create GNN for each of the dimensions and later combine them into a single network.
#
# 1. Each dimension is a separate graph and gets its own GNN.
# 2. Dimensions are connected in a MLP layer.

# %% [markdown]
# #### Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch.optim as optim
from torch.utils.data import TensorDataset, random_split
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
import country_converter as coco
import functools
import os
from torchmetrics.regression import MeanAbsolutePercentageError
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

# Set up device (is available use GPU to speed up computations)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

os.chdir('/home/jovyan/dlss-project')
print("Current working directory:", os.getcwd())
# Out:
# cuda
# Current working directory: /home/jovyan/dlss-project

# %% [markdown]
# ## Data

# %%
path_geo_edges = "data_collection/geography/edges_yearly_dist_enc.parquet"
path_geo_nodes = "data_collection/geography/nodes_enc.parquet"
df_geo_edges = pd.read_parquet(path_geo_edges)
df_geo_nodes = pd.read_parquet(path_geo_nodes)

path_pol_edges = "data_collection/political/data/edge_features.parquet"
path_pol_nodes = "data_collection/political/data/node_features.parquet"
df_pol_edges = pd.read_parquet(path_pol_edges)
df_pol_nodes = pd.read_parquet(path_pol_nodes)

path_cult_edges = "data_collection/culture/culture_edges.parquet"
path_cult_nodes = "data_collection/culture/culture_nodes.parquet"
df_cult_edges = pd.read_parquet(path_cult_edges)
df_cult_nodes = pd.read_parquet(path_cult_nodes)

path_lang_edges = "data_collection/culture/language_religion_edges.parquet"
path_lang_nodes = "data_collection/culture/language_religion_nodes.parquet"
df_lang_edges = pd.read_parquet(path_lang_edges)
df_lang_nodes = pd.read_parquet(path_lang_nodes)

path_eco_edges = "data_collection/economics/edges_economics.parquet"
path_eco_nodes = "data_collection/economics/nodes_economics.parquet"
df_eco_edges = pd.read_parquet(path_eco_edges)
df_eco_nodes = pd.read_parquet(path_eco_nodes)

path_gini = "data_collection/gini.parquet"
df_gini = pd.read_parquet(path_gini)
df_gini = df_gini[df_gini['year'].between(2000, 2022)].reset_index(drop=True)

# %%
# Pre-compute UN member countries once
@functools.lru_cache(maxsize=1)
def get_un_countries():
    """Cache UN member countries to avoid repeated lookups"""
    iso3 = coco.CountryConverter().data[coco.CountryConverter().data['UNmember'].notna()]['ISO3'].dropna().tolist()
    unnumeric = coco.CountryConverter().data[coco.CountryConverter().data['UNmember'].notna()]['UNcode'].dropna().tolist()
    return iso3, unnumeric


@functools.lru_cache(maxsize=1000)
def convert_country_code(country, target_format='UNnumeric'):
    """Cache country code conversions"""
    return coco.convert(names=country, to=target_format, not_found=None)


def prepare_frames(edge_df, node_df, edge_country_a_col, edge_country_b_col, node_country_col, year_col="year"):
    """
    Filter to UN members, map country ids, coerce dtypes, but DO NOT scale yet.
    Returns:
      edge_df, node_df, edge_feature_cols, node_feature_cols, usable_years
    """
    uno_iso3_codes, _ = get_un_countries()

    # Filter to UN members (both ends for edges; country for nodes)
    edge_mask = edge_df[edge_country_a_col].isin(uno_iso3_codes) & edge_df[edge_country_b_col].isin(uno_iso3_codes)
    node_mask = node_df[node_country_col].isin(uno_iso3_codes)
    edge_df = edge_df[edge_mask].copy()
    node_df = node_df[node_mask].copy()

    # Ensure year int
    edge_df[year_col] = edge_df[year_col].astype(int)
    node_df[year_col] = node_df[year_col].astype(int)

    # Vectorized country code conversion
    unique_countries_edges = pd.concat([edge_df[edge_country_a_col], edge_df[edge_country_b_col]]).unique()
    unique_countries_nodes = node_df[node_country_col].unique()
    all_unique_countries = np.unique(np.concatenate([unique_countries_edges, unique_countries_nodes]))

    country_to_id_map = dict(zip(
        all_unique_countries,
        coco.convert(all_unique_countries.tolist(), to='UNnumeric', not_found=None)
    ))

    # Apply mapping
    edge_df['country_id_a'] = edge_df[edge_country_a_col].map(country_to_id_map)
    edge_df['country_id_b'] = edge_df[edge_country_b_col].map(country_to_id_map)
    node_df['country_id'] = node_df[node_country_col].map(country_to_id_map)

    # Drop unmapped
    edge_df = edge_df.dropna(subset=['country_id_a', 'country_id_b'])
    node_df = node_df.dropna(subset=['country_id'])

    # Cast ids
    edge_df['country_id_a'] = edge_df['country_id_a'].astype(int)
    edge_df['country_id_b'] = edge_df['country_id_b'].astype(int)
    node_df['country_id'] = node_df['country_id'].astype(int)

    # Feature columns (exclude ids & year; keep original code cols for edges out)
    edge_feature_cols = [
        c for c in edge_df.columns
        if c not in [edge_country_a_col, edge_country_b_col, year_col, 'country_id_a', 'country_id_b']
    ]
    node_feature_cols = [
        c for c in node_df.columns
        if c not in [node_country_col, year_col, 'country_id']
    ]

    # Convert bools once (faster than per-year)
    bool_cols_edges = edge_df[edge_feature_cols].select_dtypes(include='bool').columns
    if len(bool_cols_edges):
        edge_df[bool_cols_edges] = edge_df[bool_cols_edges].astype(int)
    bool_cols_nodes = node_df[node_feature_cols].select_dtypes(include='bool').columns
    if len(bool_cols_nodes):
        node_df[bool_cols_nodes] = node_df[bool_cols_nodes].astype(int)

    # Years we’ll build graphs for (restricted to 2000–2022)
    years = sorted(set(edge_df[year_col]).intersection(set(range(2000, 2023))))

    return edge_df, node_df, edge_feature_cols, node_feature_cols, years

def fit_apply_scalers(node_df, edge_df, node_feature_cols, edge_feature_cols, train_years, year_col='year'):
    """
    Fit StandardScaler on TRAIN YEARS ONLY; transform all years (prevents leakage).
    """
    # Fit on train years only
    node_train = node_df[node_df[year_col].isin(train_years)]
    edge_train = edge_df[edge_df[year_col].isin(train_years)]

    node_scaler = StandardScaler().fit(node_train[node_feature_cols]) if node_feature_cols else None
    edge_scaler = StandardScaler().fit(edge_train[edge_feature_cols]) if edge_feature_cols else None

    # Transform full data
    if node_feature_cols:
        node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
    if edge_feature_cols:
        edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])

    return node_df, edge_df

def build_year_graphs(edge_df, node_df, years, edge_feature_cols, node_feature_cols, uno_unnumeric_codes, year_col='year'):
    """
    Build one PyG Data per year (same as your original create_data's per-year section),
    but assumes scaling already applied.
    """
    data_dict = {}
    for year in years:
        edge_df_year = edge_df[edge_df[year_col] == year]
        node_df_year = node_df[node_df[year_col] == year].copy()

        # Drop duplicate nodes per (country_id, year)
        node_df_year = node_df_year.drop_duplicates(subset=['country_id', year_col], keep='first')

        # Ensure exists flag & fill missing countries for the year
        node_df_year['exists'] = 1
        existing = set(node_df_year['country_id'])
        missing = set(uno_unnumeric_codes) - existing
        if missing:
            missing_rows = pd.DataFrame({
                'country_id': list(missing),
                year_col: year,
                **{c: 0 for c in node_feature_cols},
                'exists': 0
            })
            node_df_year = pd.concat([node_df_year, missing_rows], ignore_index=True)

        node_df_year_sorted = node_df_year.sort_values(by='country_id').reset_index(drop=True)

        # Build tensors
        node_features = torch.tensor(
            node_df_year_sorted[node_feature_cols].apply(pd.to_numeric, errors='coerce').fillna(0).values,
            dtype=torch.float32
        )
        country_id_tensor = torch.tensor(node_df_year_sorted['country_id'].values, dtype=torch.long)

        edge_features_df = edge_df_year[edge_feature_cols].copy()
        edge_features_df = edge_features_df.apply(pd.to_numeric, errors='coerce').fillna(0)
        edge_attr = torch.from_numpy(edge_features_df.values.astype(np.float32))

        # Map edge indices to node positions
        pos_map = {cid: i for i, cid in enumerate(node_df_year_sorted['country_id'].values)}
        edge_index = torch.tensor(
            [
                edge_df_year['country_id_a'].map(pos_map).values,
                edge_df_year['country_id_b'].map(pos_map).values
            ],
            dtype=torch.long
        )

        data = Data(x=node_features, edge_index=edge_index, edge_attr=edge_attr, country_id=country_id_tensor)
        data_dict[year] = data

    return data_dict

# ----------------- Gini handling (unchanged from your Prep 2) -----------------
def create_gini_data(df_gini, year_col='year', country_col='country', gini_col='gini'):
    uno_iso3_codes, _ = get_un_countries()
    df_gini = df_gini[df_gini[country_col].isin(uno_iso3_codes)].copy()
    df_gini['country_id'] = df_gini[country_col].map(lambda x: convert_country_code(x, 'UNnumeric'))
    df_gini = df_gini.sort_values(by=['country_id']).reset_index(drop=True)
    df_gini = df_gini.dropna(subset=['country_id'])
    df_gini[gini_col] = df_gini[gini_col] / 100
    df_gini['exists'] = 1
    df_gini.loc[df_gini[gini_col].isna(), 'exists'] = 0
    df_gini.loc[df_gini[gini_col].isna(), gini_col] = 0

    gini_data_dict = {}
    years = df_gini[year_col].unique()
    for year in years:
        df_year = df_gini[df_gini[year_col] == year].copy()
        df_year['country_id'] = df_year['country_id'].astype(int)
        gini_tensor = torch.tensor(df_year[gini_col].values, dtype=torch.float32)
        country_id_tensor = torch.tensor(df_year['country_id'].values, dtype=torch.long)
        data = Data(y=gini_tensor.unsqueeze(1), country_id=country_id_tensor, exists=df_year['exists'].values)
        gini_data_dict[year] = data
    return gini_data_dict

# ----------------- Orchestration per modality with proper scaling -----------------

from sklearn.model_selection import train_test_split

def build_modality(edge_df, node_df, edge_country_a_col, edge_country_b_col, node_country_col, year_col="year"):
    """
    Full pipeline for a modality:
      1) prepare frames (no scaling)
      2) split years
      3) fit scalers on TRAIN years only
      4) build per-year graphs from scaled frames
    Returns: (data_by_year, train_years, val_years, test_years)
    """
    uno_iso3_codes, uno_unnumeric_codes = get_un_countries()

    # 1) prepare
    edge_df, node_df, edge_feature_cols, node_feature_cols, years = prepare_frames(
        edge_df, node_df, edge_country_a_col, edge_country_b_col, node_country_col, year_col=year_col
    )

    # 2) year split 
    all_years = sorted(years)
    train_years, test_years = train_test_split(all_years, test_size=0.2, random_state=42)
    train_years, val_years = train_test_split(train_years, test_size=0.25, random_state=42)  # 0.25 of 0.8 = 0.2

    # 3) fit scaling 
    node_df, edge_df = fit_apply_scalers(
        node_df, edge_df, node_feature_cols, edge_feature_cols, train_years, year_col=year_col
    )

    # 4) build per-year graphs
    data_by_year = build_year_graphs(
        edge_df, node_df, years, edge_feature_cols, node_feature_cols, uno_unnumeric_codes, year_col=year_col
    )

    return data_by_year, train_years, val_years, test_years

# %%
# ----------------- Build all modalities -----------------

geo_data, geo_train_years, geo_val_years, geo_test_years = build_modality(
    df_geo_edges, df_geo_nodes, 'iso_o', 'iso_d', 'code_3', year_col='year'
)
pol_data, pol_train_years, pol_val_years, pol_test_years = build_modality(
    df_pol_edges, df_pol_nodes, 'state1', 'state2', 'country', year_col='year'
)
cul_data, cul_train_years, cul_val_years, cul_test_years = build_modality(
    df_cult_edges, df_cult_nodes, 'ISO3_a', 'ISO3_b', 'ISO3', year_col='year'
)
lang_data, lang_train_years, lang_val_years, lang_test_years = build_modality(
    df_lang_edges, df_lang_nodes, 'country_a', 'country_b', 'ISO3', year_col='year'
)
eco_data, eco_train_years, eco_val_years, eco_test_years = build_modality(
    df_eco_edges, df_eco_nodes, 'src_ISO3', 'tgt_ISO3', 'ISO3', year_col='year'
)


gini_data = create_gini_data(df_gini, year_col='year', country_col='country', gini_col='gini')

data_years = {}
common_years = sorted(set(geo_data.keys()) & set(pol_data.keys()) & set(cul_data.keys()) & set(lang_data.keys()) & set(eco_data.keys()))
for year in common_years:
    data_years[year] = {
        'geography': geo_data[year],
        'political': pol_data[year],
        'culture': cul_data[year],
        'language': lang_data[year],
        'economy': eco_data[year],
        'GINI': gini_data.get(year) 
    }


network_dimesions = {
    'geography': {
        'node_features': data_years[2000]['geography'].x.shape[1],
        'edge_features': data_years[2000]['geography'].edge_attr.shape[1]
    },
    'political': {
        'node_features': data_years[2000]['political'].x.shape[1],
        'edge_features': data_years[2000]['political'].edge_attr.shape[1]
    },
    'culture': {
        'node_features': data_years[2000]['culture'].x.shape[1],
        'edge_features': data_years[2000]['culture'].edge_attr.shape[1]
    },
    'language': {
        'node_features': data_years[2000]['language'].x.shape[1],
        'edge_features': data_years[2000]['language'].edge_attr.shape[1]
    },
    'economy': {
        'node_features': data_years[2000]['economy'].x.shape[1],
        'edge_features': data_years[2000]['economy'].edge_attr.shape[1]
    },
}

all_years = sorted(data_years.keys())
train_years, test_years = train_test_split(all_years, test_size=0.2, random_state=42)
train_years, val_years = train_test_split(train_years, test_size=0.25, random_state=42)

train_set = [data_years[y] for y in train_years]
val_set   = [data_years[y] for y in val_years]
test_set  = [data_years[y] for y in test_years]
# Out:
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.61969166 -0.61969166 -0.61969166 ...  1.61370575  1.61370575
#   1.61370575]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.47238607 -0.47238607 -0.47238607 ... -0.47238607 -0.47238607
#  -0.47238607]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.75741987  1.75741987  1.75741987 ... -0.56901599 -0.56901599
#  -0.56901599]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.53500469 -0.53500469 -0.53500469 ... -0.53500469 -0.53500469
#  -0.53500469]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.28057035 -0.28057035 -0.28057035 ... -0.28057035 -0.28057035
#  -0.28057035]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.1026394 -0.1026394 -0.1026394 ... -0.1026394 -0.1026394 -0.1026394]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.26960744 -0.26960744 -0.26960744 ... -0.26960744 -0.26960744
#  -0.26960744]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.20860164 -0.20860164 -0.20860164 ... -0.20860164 -0.20860164
#  -0.20860164]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.16358479 -0.16358479 -0.16358479 ... -0.16358479 -0.16358479
#  -0.16358479]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.31796816 -0.31796816 -0.31796816 ...  3.14496895  3.14496895
#   3.14496895]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.16358479 -0.16358479 -0.16358479 ... -0.16358479 -0.16358479
#  -0.16358479]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.23450275 -0.23450275 -0.23450275 ... -0.23450275 -0.23450275
#  -0.23450275]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.14592471 -0.14592471 -0.14592471 ... -0.14592471 -0.14592471
#  -0.14592471]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.16358479 -0.16358479 -0.16358479 ... -0.16358479 -0.16358479
#  -0.16358479]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.22185966 -0.22185966 -0.22185966 ... -0.22185966 -0.22185966
#  -0.22185966]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.1736457 -0.1736457 -0.1736457 ... -0.1736457 -0.1736457 -0.1736457]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.1026394 -0.1026394 -0.1026394 ... -0.1026394 -0.1026394 -0.1026394]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.23450275 -0.23450275 -0.23450275 ... -0.23450275 -0.23450275
#  -0.23450275]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.12603947 -0.12603947 -0.12603947 ... -0.12603947 -0.12603947
#  -0.12603947]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.2583093 -0.2583093 -0.2583093 ... -0.2583093 -0.2583093 -0.2583093]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.24662762 -0.24662762 -0.24662762 ... -0.24662762 -0.24662762
#  -0.24662762]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.16358479 -0.16358479 -0.16358479 ... -0.16358479 -0.16358479
#  -0.16358479]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 4.50735392  4.50735392  4.50735392 ... -0.22185966 -0.22185966
#  -0.22185966]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.27723032 -0.27723032 -0.27723032 ... -0.27723032 -0.27723032
#  -0.27723032]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.30164321 -0.30164321 -0.30164321 ... -0.30164321 -0.30164321
#  -0.30164321]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.3110399 -0.3110399 -0.3110399 ... -0.3110399 -0.3110399 -0.3110399]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:94: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.22185966 -0.22185966 -0.22185966 ... -0.22185966 -0.22185966
#  -0.22185966]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   node_df.loc[:, node_feature_cols] = node_scaler.transform(node_df[node_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.08514937 -0.80678319 -0.4832225  ... -0.88868588 -1.28318527
#  -1.67859804]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.0819135  -0.8036067  -0.48001938 ... -0.88551613 -1.55850618
#  -1.6754933 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.12838815  0.12838815  0.12838815 ...  0.12838815 -7.78888096
#  -7.78888096]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.12838815 -0.12838815 -0.12838815 ... -0.12838815  7.78888096
#   7.78888096]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.43106242  0.43106242  0.43106242 ...  0.43106242 -2.31984963
#  -2.31984963]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.43106242 -0.43106242 -0.43106242 ... -0.43106242  2.31984963
#   2.31984963]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.4080104   0.4080104   0.4080104  ...  0.4080104  -2.45091794
#  -2.45091794]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.4080104  -0.4080104  -0.4080104  ... -0.4080104   2.45091794
#   2.45091794]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.10625142 0.10625142 0.10625142 ... 0.10625142 0.10625142 0.10625142]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.10625142 -0.10625142 -0.10625142 ... -0.10625142 -0.10625142
#  -0.10625142]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.35259452  0.35259452  0.35259452 ... -2.83611894  0.35259452
#  -2.83611894]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.35259452 -0.35259452 -0.35259452 ...  2.83611894 -0.35259452
#   2.83611894]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01084079 0.01084079 0.01084079 ... 0.01084079 0.01084079 0.01084079]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.01084079 -0.01084079 -0.01084079 ... -0.01084079 -0.01084079
#  -0.01084079]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08283889 0.08283889 0.08283889 ... 0.08283889 0.08283889 0.08283889]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.08283889 -0.08283889 -0.08283889 ... -0.08283889 -0.08283889
#  -0.08283889]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:142: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   edge_index = torch.tensor(
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-3.20185769 -3.20185769 -3.20185769 ...  0.31231869  0.31231869
#   0.31231869]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.17166589 -0.17166589 -0.17166589 ... -0.17166589 -0.17166589
#  -0.17166589]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.41692028  0.41692028  0.41692028 ...  0.41692028 -2.3985401
#  -2.3985401 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.39193463 -0.39193463 -0.39193463 ... -0.39193463 -0.39193463
#  -0.39193463]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])
# /tmp/ipykernel_1366/435830011.py:96: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.62380433  0.62380433  0.62380433 ... -1.60306678 -1.60306678
#  -1.60306678]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edge_df.loc[:, edge_feature_cols] = edge_scaler.transform(edge_df[edge_feature_cols])

# %%
print("Train years:", len(train_set))
print("Validation years:", len(val_set))
print("Test years:", len(test_set))
# Out:
# Train years: 13
# Validation years: 5
# Test years: 5

# %%
network_dimesions
# Out:
# {'geography': {'node_features': 28, 'edge_features': 16},
#  'political': {'node_features': 7, 'edge_features': 5},
#  'culture': {'node_features': 6, 'edge_features': 11},
#  'language': {'node_features': 7, 'edge_features': 2},
#  'economy': {'node_features': 3, 'edge_features': 1}}

# %% [markdown]
# ## Model Setup

# %%
# GNN model for each of the different networks
class DimensionModel(torch.nn.Module):
    def __init__(self, num_node_features, num_edge_features, hidden_size=64, target_size=1, n_gat_layers=2, n_mlp_layers=2):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_node_features = num_node_features
        self.num_edge_features = num_edge_features
        self.target_size = target_size
        # Dynamically create GAT layers
        self.convs = nn.ModuleList()
        self.convs.append(GATv2Conv(self.num_node_features, self.hidden_size, edge_dim=num_edge_features))
        for _ in range(n_gat_layers - 1):
            self.convs.append(GATv2Conv(self.hidden_size, self.hidden_size, edge_dim=num_edge_features))

        # Dynamically create MLP layers
        self.n_mlp_layers = n_mlp_layers
        mlp_layers = []
        for _ in range(n_mlp_layers):
            mlp_layers.append(nn.Linear(self.hidden_size, self.hidden_size))
            mlp_layers.append(nn.ReLU())
            mlp_layers.append(nn.Dropout(0.2))
        self.mlp = nn.Sequential(*mlp_layers)
        
    def forward(self, data):
        x, edge_index, edge_attr = data.x, data.edge_index, data.edge_attr
        for conv in self.convs[:-1]:
            x = conv(x, edge_index, edge_attr=edge_attr)
            x = F.relu(x)
            x = F.dropout(x, training=self.training)
        x = self.convs[-1](x, edge_index, edge_attr=edge_attr)
        if self.n_mlp_layers > 0:
            x = self.mlp(x)  # Apply the fully connected layer
        return x
    
class MultiModalGNNModel(nn.Module):
    def __init__(self, 
                 input_dims,
                 hidden_size=64,
                 final_output_size=1, 
                 n_gat_layers=2,
                 n_dim_mlp_layers=2,
                 combination_method='concat',
                 mlp_variant='default'):
        super().__init__()
        self.combination_method = combination_method

        self.geo_model = DimensionModel(input_dims['geography']['node_features'], input_dims['geography']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.pol_model = DimensionModel(input_dims['political']['node_features'], input_dims['political']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.cult_model = DimensionModel(input_dims['culture']['node_features'], input_dims['culture']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.lang_model = DimensionModel(input_dims['language']['node_features'], input_dims['language']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)
        self.eco_model = DimensionModel(input_dims['economy']['node_features'], input_dims['economy']['edge_features'], hidden_size, n_gat_layers=n_gat_layers, n_mlp_layers=n_dim_mlp_layers)

        self.num_modalities = 5
        self.hidden_size = hidden_size

        if self.combination_method == 'attention':
            # Learnable attention weights for each modality
            self.attn_weights = nn.Parameter(torch.ones(self.num_modalities))

        self.fusion_input_size = hidden_size * self.num_modalities if combination_method == 'concat' else hidden_size
        if mlp_variant == 'default':
            self.mlp = nn.Sequential(
                nn.Linear(self.fusion_input_size, 1024),
                nn.BatchNorm1d(1024),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(1024, 256),
                nn.BatchNorm1d(256),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(256, final_output_size)
            )
        elif mlp_variant == 'deep':
            # Deeper MLP variant
            self.mlp = nn.Sequential(
                nn.Linear(self.fusion_input_size, 2048),
                nn.BatchNorm1d(2048),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(2048, 1024),
                nn.BatchNorm1d(1024),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(1024, 512),
                nn.BatchNorm1d(512),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(512, final_output_size)
            )
        elif mlp_variant == 'shallow':
            # Shallow MLP variant
            self.mlp = nn.Sequential(
                nn.Linear(self.fusion_input_size, 512),
                nn.BatchNorm1d(512),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(512, 256),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(256, final_output_size)
            )        
    

    def forward(self, data_dict):
        geo_emb = self.geo_model(data_dict['geography'])
        pol_emb = self.pol_model(data_dict['political'])
        cult_emb = self.cult_model(data_dict['culture'])
        lang_emb = self.lang_model(data_dict['language'])
        eco_emb = self.eco_model(data_dict['economy'])

        embeddings = [geo_emb, pol_emb, cult_emb, lang_emb, eco_emb]

        if self.combination_method == 'concat':
            # Concatenate embeddings along the last dimension
            fused = torch.cat(embeddings, dim=-1)
        elif self.combination_method == 'attention':
            # Stack embeddings: shape [num_nodes, num_modalities, hidden_size]
            stacked = torch.stack(embeddings, dim=1)  # [num_nodes, num_modalities, hidden_size]
            attn = torch.softmax(self.attn_weights, dim=0)  # [num_modalities]
            attn = attn.view(1, self.num_modalities, 1)     # [1, num_modalities, 1] for broadcasting
            fused = (stacked * attn).sum(dim=1)             # [num_nodes, hidden_size]
        output = self.mlp(fused)
        return output

# %% [markdown]
# ## Training Setup

# %%
class EarlyStopping:
    def __init__(self, patience=25, min_delta=0.0001, path='checkpoint.pt', printing=True):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.path = path  # Path to save the best model
        self.printing = printing
        
        # remove model if path already exists
        if os.path.exists(path):
          os.remove(path)
          if self.printing:
            print(f"Removing existing model at: {path}")

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            if val_loss < self.best_loss:
                self.save_checkpoint(val_loss, model)
                self.best_loss = val_loss
                self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        torch.save(model.state_dict(), self.path)
        if self.printing:
            print(f'Validation loss decreased ({self.best_loss:.6f} --> {val_loss:.6f}).  Saving model ...')
        
        
def train_gnn(epochs, model, optimizer, criterion, train_loader, val_loader, early_stopper, printing=True):    
    # Make sure device is defined
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Move the data and model to the device
    # data_dict = move_data_to_device(data_dict, device)

    # model = model.to(device)

    train_losses = []
    val_losses = []
    
    if printing:
        print("Starting training...")

    for epoch in range(epochs):
        model.train()
        train_loss_temp = 0
        for data_dict in train_loader:
            # Training

            optimizer.zero_grad()

            # Forward pass on the entire graph
            output = model(data_dict)
            mask = torch.tensor(data_dict['GINI'].exists, dtype=torch.bool, device=output.device).flatten()
            target = data_dict['GINI'].y

            # Calculate loss using only valid entries
            train_loss = criterion(output[mask], target[mask])

            # Backward pass
            train_loss.backward()
            optimizer.step()
            train_loss_temp += train_loss.item()

        train_losses.append(train_loss_temp / len(train_loader))

        # Validation
        model.eval()
        val_loss_temp = 0
        with torch.no_grad():
            for data_dict in val_loader:
                output = model(data_dict)
                mask = torch.tensor(data_dict['GINI'].exists, dtype=torch.bool, device=output.device).flatten()
                target = data_dict['GINI'].y
                val_loss = criterion(output[mask], target[mask])
                val_loss_temp += val_loss.item()
        val_losses.append(val_loss_temp / len(val_loader))
        if printing:
            print(f'Epoch: {epoch+1}, Training Loss: {train_loss.item():.4f}, Validation Loss: {val_loss.item():.4f}')

        # Early stopping
        early_stopper(val_loss, model)
        if early_stopper.early_stop:
            if printing:
                print("Early stopping triggered.")
            break

    # Load the best model weights
    model.load_state_dict(torch.load(early_stopper.path))
    return train_losses, val_losses

# %% [markdown]
# ## Training

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def move_data_dict_to_device(data_dict, device):
    moved = {}
    for k, v in data_dict.items():
        if hasattr(v, 'to'):
            moved[k] = v.to(device)
        else:
            moved[k] = v
    return moved

train_set = [move_data_dict_to_device(d, device) for d in train_set]
val_set = [move_data_dict_to_device(d, device) for d in val_set]
test_set = [move_data_dict_to_device(d, device) for d in test_set]

train_loader = DataLoader(train_set, batch_size=3, shuffle=True)
val_loader = DataLoader(val_set, batch_size=3, shuffle=False)
test_loader = DataLoader(test_set, batch_size=3, shuffle=False)

# %%
gan_model = MultiModalGNNModel(
    input_dims=network_dimesions, hidden_size=148, n_dim_mlp_layers=0, combination_method="attention", mlp_variant="deep", n_gat_layers=1)

gan_model = gan_model.to(device)

# criterion for regression task
criterion = nn.L1Loss()

# Fix 7: Better optimizer settings for this problem
optimizer = optim.Adam(gan_model.parameters(), lr=0.0006502342591153078, weight_decay=0.0000003414375524585915)  # Lower LR and weight decay

# Initialize early stopping
early_stopper = EarlyStopping(patience=60, min_delta=0.0001, path='model_checkpoints/gan_checkpoint.pt')

# Train the model
epochs = 1000
train_losses_gan, val_losses_gan = train_gnn(epochs, gan_model, optimizer, criterion, train_loader, val_loader, early_stopper)

# Plot results
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses_gan, label='Training Loss')
plt.plot(val_losses_gan, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Progress')
# Out:
# Removing existing model at: model_checkpoints/gan_checkpoint.pt
# Starting training...
# Epoch: 1, Training Loss: 0.4000, Validation Loss: 0.2737
# Validation loss decreased (0.273700 --> 0.273700).  Saving model ...
# Epoch: 2, Training Loss: 0.3321, Validation Loss: 0.1322
# Validation loss decreased (0.273700 --> 0.132160).  Saving model ...
# Epoch: 3, Training Loss: 0.3099, Validation Loss: 0.1058
# Validation loss decreased (0.132160 --> 0.105765).  Saving model ...
# Epoch: 4, Training Loss: 0.2062, Validation Loss: 0.0913
# Validation loss decreased (0.105765 --> 0.091279).  Saving model ...
# Epoch: 5, Training Loss: 0.1757, Validation Loss: 0.0885
# Validation loss decreased (0.091279 --> 0.088487).  Saving model ...
# Epoch: 6, Training Loss: 0.1706, Validation Loss: 0.0813
# Validation loss decreased (0.088487 --> 0.081347).  Saving model ...
# Epoch: 7, Training Loss: 0.1305, Validation Loss: 0.0825
# Epoch: 8, Training Loss: 0.1285, Validation Loss: 0.0817
# Epoch: 9, Training Loss: 0.1115, Validation Loss: 0.0763
# Validation loss decreased (0.081347 --> 0.076296).  Saving model ...
# Epoch: 10, Training Loss: 0.1310, Validation Loss: 0.0615
# Validation loss decreased (0.076296 --> 0.061510).  Saving model ...
# Epoch: 11, Training Loss: 0.1089, Validation Loss: 0.0480
# Validation loss decreased (0.061510 --> 0.047995).  Saving model ...
# Epoch: 12, Training Loss: 0.0819, Validation Loss: 0.0528
# Epoch: 13, Training Loss: 0.0762, Validation Loss: 0.0502
# Epoch: 14, Training Loss: 0.0738, Validation Loss: 0.0647
# Epoch: 15, Training Loss: 0.0619, Validation Loss: 0.0761
# Epoch: 16, Training Loss: 0.0608, Validation Loss: 0.0432
# Validation loss decreased (0.047995 --> 0.043237).  Saving model ...
# Epoch: 17, Training Loss: 0.0585, Validation Loss: 0.0504
# Epoch: 18, Training Loss: 0.0834, Validation Loss: 0.0422
# Validation loss decreased (0.043237 --> 0.042207).  Saving model ...
# Epoch: 19, Training Loss: 0.0875, Validation Loss: 0.0497
# Epoch: 20, Training Loss: 0.0860, Validation Loss: 0.0426
# Epoch: 21, Training Loss: 0.0644, Validation Loss: 0.0487
# Epoch: 22, Training Loss: 0.0401, Validation Loss: 0.0470
# Epoch: 23, Training Loss: 0.0521, Validation Loss: 0.0404
# Validation loss decreased (0.042207 --> 0.040393).  Saving model ...
# Epoch: 24, Training Loss: 0.0682, Validation Loss: 0.0507
# Epoch: 25, Training Loss: 0.0358, Validation Loss: 0.0434
# Epoch: 26, Training Loss: 0.0450, Validation Loss: 0.0414
# Epoch: 27, Training Loss: 0.0644, Validation Loss: 0.0493
# Epoch: 28, Training Loss: 0.0672, Validation Loss: 0.0427
# Epoch: 29, Training Loss: 0.0974, Validation Loss: 0.0547
# Epoch: 30, Training Loss: 0.0615, Validation Loss: 0.0472
# Epoch: 31, Training Loss: 0.0556, Validation Loss: 0.0428
# Epoch: 32, Training Loss: 0.0402, Validation Loss: 0.0371
# Validation loss decreased (0.040393 --> 0.037143).  Saving model ...
# Epoch: 33, Training Loss: 0.0343, Validation Loss: 0.0340
# Validation loss decreased (0.037143 --> 0.034027).  Saving model ...
# Epoch: 34, Training Loss: 0.0454, Validation Loss: 0.0417
# Epoch: 35, Training Loss: 0.0352, Validation Loss: 0.0323
# Validation loss decreased (0.034027 --> 0.032342).  Saving model ...
# Epoch: 36, Training Loss: 0.0661, Validation Loss: 0.0288
# Validation loss decreased (0.032342 --> 0.028796).  Saving model ...
# Epoch: 37, Training Loss: 0.0558, Validation Loss: 0.0299
# Epoch: 38, Training Loss: 0.0451, Validation Loss: 0.0468
# Epoch: 39, Training Loss: 0.0532, Validation Loss: 0.0438
# Epoch: 40, Training Loss: 0.0355, Validation Loss: 0.0441
# Epoch: 41, Training Loss: 0.0369, Validation Loss: 0.0521
# Epoch: 42, Training Loss: 0.0357, Validation Loss: 0.0300
# Epoch: 43, Training Loss: 0.0284, Validation Loss: 0.0261
# Validation loss decreased (0.028796 --> 0.026136).  Saving model ...
# Epoch: 44, Training Loss: 0.0711, Validation Loss: 0.0384
# Epoch: 45, Training Loss: 0.0584, Validation Loss: 0.0260
# Validation loss decreased (0.026136 --> 0.026032).  Saving model ...
# Epoch: 46, Training Loss: 0.0415, Validation Loss: 0.0411
# Epoch: 47, Training Loss: 0.0338, Validation Loss: 0.0317
# Epoch: 48, Training Loss: 0.0393, Validation Loss: 0.0462
# Epoch: 49, Training Loss: 0.0616, Validation Loss: 0.0490
# Epoch: 50, Training Loss: 0.0572, Validation Loss: 0.0319
# Epoch: 51, Training Loss: 0.0582, Validation Loss: 0.0285
# Epoch: 52, Training Loss: 0.0294, Validation Loss: 0.0426
# Epoch: 53, Training Loss: 0.0586, Validation Loss: 0.0346
# Epoch: 54, Training Loss: 0.0296, Validation Loss: 0.0511
# Epoch: 55, Training Loss: 0.0598, Validation Loss: 0.0315
# Epoch: 56, Training Loss: 0.0308, Validation Loss: 0.0463
# Epoch: 57, Training Loss: 0.0455, Validation Loss: 0.0430
# Epoch: 58, Training Loss: 0.0432, Validation Loss: 0.0260
# Epoch: 59, Training Loss: 0.0674, Validation Loss: 0.0227
# Validation loss decreased (0.026032 --> 0.022735).  Saving model ...
# Epoch: 60, Training Loss: 0.0735, Validation Loss: 0.0338
# Epoch: 61, Training Loss: 0.0379, Validation Loss: 0.0404
# Epoch: 62, Training Loss: 0.0303, Validation Loss: 0.0292
# Epoch: 63, Training Loss: 0.0312, Validation Loss: 0.0317
# Epoch: 64, Training Loss: 0.0565, Validation Loss: 0.0326
# Epoch: 65, Training Loss: 0.0424, Validation Loss: 0.0278
# Epoch: 66, Training Loss: 0.0603, Validation Loss: 0.0361
# Epoch: 67, Training Loss: 0.0511, Validation Loss: 0.0241
# Epoch: 68, Training Loss: 0.0397, Validation Loss: 0.0242
# Epoch: 69, Training Loss: 0.0317, Validation Loss: 0.0267
# Epoch: 70, Training Loss: 0.0362, Validation Loss: 0.0242
# Epoch: 71, Training Loss: 0.0338, Validation Loss: 0.0270
# Epoch: 72, Training Loss: 0.0324, Validation Loss: 0.0250
# Epoch: 73, Training Loss: 0.0423, Validation Loss: 0.0245
# Epoch: 74, Training Loss: 0.0491, Validation Loss: 0.0342
# Epoch: 75, Training Loss: 0.0288, Validation Loss: 0.0311
# Epoch: 76, Training Loss: 0.0306, Validation Loss: 0.0297
# Epoch: 77, Training Loss: 0.0401, Validation Loss: 0.0230
# Epoch: 78, Training Loss: 0.0387, Validation Loss: 0.0358
# Epoch: 79, Training Loss: 0.0353, Validation Loss: 0.0252
# Epoch: 80, Training Loss: 0.0287, Validation Loss: 0.0219
# Validation loss decreased (0.022735 --> 0.021867).  Saving model ...
# Epoch: 81, Training Loss: 0.0258, Validation Loss: 0.0258
# Epoch: 82, Training Loss: 0.0300, Validation Loss: 0.0279
# Epoch: 83, Training Loss: 0.0215, Validation Loss: 0.0249
# Epoch: 84, Training Loss: 0.0393, Validation Loss: 0.0313
# Epoch: 85, Training Loss: 0.0325, Validation Loss: 0.0238
# Epoch: 86, Training Loss: 0.0285, Validation Loss: 0.0304
# Epoch: 87, Training Loss: 0.0260, Validation Loss: 0.0264
# Epoch: 88, Training Loss: 0.0374, Validation Loss: 0.0252
# Epoch: 89, Training Loss: 0.0299, Validation Loss: 0.0225
# Epoch: 90, Training Loss: 0.0360, Validation Loss: 0.0238
# Epoch: 91, Training Loss: 0.0258, Validation Loss: 0.0241
# Epoch: 92, Training Loss: 0.0436, Validation Loss: 0.0254
# Epoch: 93, Training Loss: 0.0255, Validation Loss: 0.0237
# Epoch: 94, Training Loss: 0.0294, Validation Loss: 0.0245
# Epoch: 95, Training Loss: 0.0240, Validation Loss: 0.0261
# Epoch: 96, Training Loss: 0.0330, Validation Loss: 0.0251
# Epoch: 97, Training Loss: 0.0302, Validation Loss: 0.0295
# Epoch: 98, Training Loss: 0.0276, Validation Loss: 0.0313
# Epoch: 99, Training Loss: 0.0232, Validation Loss: 0.0252
# Epoch: 100, Training Loss: 0.0425, Validation Loss: 0.0266
# Epoch: 101, Training Loss: 0.0222, Validation Loss: 0.0234
# Epoch: 102, Training Loss: 0.0400, Validation Loss: 0.0254
# Epoch: 103, Training Loss: 0.0288, Validation Loss: 0.0243
# Epoch: 104, Training Loss: 0.0188, Validation Loss: 0.0222
# Epoch: 105, Training Loss: 0.0252, Validation Loss: 0.0221
# Epoch: 106, Training Loss: 0.0267, Validation Loss: 0.0243
# Epoch: 107, Training Loss: 0.0357, Validation Loss: 0.0242
# Epoch: 108, Training Loss: 0.0373, Validation Loss: 0.0248
# Epoch: 109, Training Loss: 0.0345, Validation Loss: 0.0222
# Epoch: 110, Training Loss: 0.0294, Validation Loss: 0.0236
# Epoch: 111, Training Loss: 0.0240, Validation Loss: 0.0253
# Epoch: 112, Training Loss: 0.0226, Validation Loss: 0.0222
# Epoch: 113, Training Loss: 0.0240, Validation Loss: 0.0226
# Epoch: 114, Training Loss: 0.0239, Validation Loss: 0.0210
# Validation loss decreased (0.021867 --> 0.020970).  Saving model ...
# Epoch: 115, Training Loss: 0.0200, Validation Loss: 0.0212
# Epoch: 116, Training Loss: 0.0229, Validation Loss: 0.0221
# Epoch: 117, Training Loss: 0.0243, Validation Loss: 0.0238
# Epoch: 118, Training Loss: 0.0242, Validation Loss: 0.0238
# Epoch: 119, Training Loss: 0.0260, Validation Loss: 0.0241
# Epoch: 120, Training Loss: 0.0249, Validation Loss: 0.0220
# Epoch: 121, Training Loss: 0.0295, Validation Loss: 0.0228
# Epoch: 122, Training Loss: 0.0206, Validation Loss: 0.0237
# Epoch: 123, Training Loss: 0.0251, Validation Loss: 0.0213
# Epoch: 124, Training Loss: 0.0265, Validation Loss: 0.0211
# Epoch: 125, Training Loss: 0.0279, Validation Loss: 0.0229
# Epoch: 126, Training Loss: 0.0254, Validation Loss: 0.0236
# Epoch: 127, Training Loss: 0.0253, Validation Loss: 0.0238
# Epoch: 128, Training Loss: 0.0257, Validation Loss: 0.0268
# Epoch: 129, Training Loss: 0.0236, Validation Loss: 0.0235
# Epoch: 130, Training Loss: 0.0262, Validation Loss: 0.0226
# Epoch: 131, Training Loss: 0.0359, Validation Loss: 0.0230
# Epoch: 132, Training Loss: 0.0257, Validation Loss: 0.0267
# Epoch: 133, Training Loss: 0.0229, Validation Loss: 0.0246
# Epoch: 134, Training Loss: 0.0342, Validation Loss: 0.0249
# Epoch: 135, Training Loss: 0.0213, Validation Loss: 0.0274
# Epoch: 136, Training Loss: 0.0241, Validation Loss: 0.0274
# Epoch: 137, Training Loss: 0.0252, Validation Loss: 0.0244
# Epoch: 138, Training Loss: 0.0208, Validation Loss: 0.0236
# Epoch: 139, Training Loss: 0.0202, Validation Loss: 0.0222
# Epoch: 140, Training Loss: 0.0203, Validation Loss: 0.0245
# Epoch: 141, Training Loss: 0.0218, Validation Loss: 0.0235
# Epoch: 142, Training Loss: 0.0212, Validation Loss: 0.0238
# Epoch: 143, Training Loss: 0.0238, Validation Loss: 0.0232
# Epoch: 144, Training Loss: 0.0223, Validation Loss: 0.0229
# Epoch: 145, Training Loss: 0.0218, Validation Loss: 0.0239
# Epoch: 146, Training Loss: 0.0235, Validation Loss: 0.0245
# Epoch: 147, Training Loss: 0.0292, Validation Loss: 0.0261
# Epoch: 148, Training Loss: 0.0195, Validation Loss: 0.0260
# Epoch: 149, Training Loss: 0.0323, Validation Loss: 0.0255
# Epoch: 150, Training Loss: 0.0236, Validation Loss: 0.0251
# Epoch: 151, Training Loss: 0.0195, Validation Loss: 0.0226
# Epoch: 152, Training Loss: 0.0187, Validation Loss: 0.0226
# Epoch: 153, Training Loss: 0.0258, Validation Loss: 0.0253
# Epoch: 154, Training Loss: 0.0185, Validation Loss: 0.0256
# Epoch: 155, Training Loss: 0.0225, Validation Loss: 0.0238
# Epoch: 156, Training Loss: 0.0209, Validation Loss: 0.0243
# Epoch: 157, Training Loss: 0.0235, Validation Loss: 0.0250
# Epoch: 158, Training Loss: 0.0175, Validation Loss: 0.0241
# Epoch: 159, Training Loss: 0.0172, Validation Loss: 0.0228
# Epoch: 160, Training Loss: 0.0161, Validation Loss: 0.0233
# Epoch: 161, Training Loss: 0.0212, Validation Loss: 0.0226
# Epoch: 162, Training Loss: 0.0231, Validation Loss: 0.0231
# Epoch: 163, Training Loss: 0.0257, Validation Loss: 0.0230
# Epoch: 164, Training Loss: 0.0287, Validation Loss: 0.0222
# Epoch: 165, Training Loss: 0.0270, Validation Loss: 0.0221
# Epoch: 166, Training Loss: 0.0180, Validation Loss: 0.0248
# Epoch: 167, Training Loss: 0.0293, Validation Loss: 0.0236
# Epoch: 168, Training Loss: 0.0198, Validation Loss: 0.0246
# Epoch: 169, Training Loss: 0.0231, Validation Loss: 0.0252
# Epoch: 170, Training Loss: 0.0182, Validation Loss: 0.0213
# Epoch: 171, Training Loss: 0.0191, Validation Loss: 0.0233
# Epoch: 172, Training Loss: 0.0277, Validation Loss: 0.0238
# Epoch: 173, Training Loss: 0.0220, Validation Loss: 0.0242
# Epoch: 174, Training Loss: 0.0248, Validation Loss: 0.0237
# Early stopping triggered.
# Text(0.5, 1.0, 'Training Progress')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_model(model, test_loader, device, printing=True):
    model.eval()
    all_true = []
    all_pred = []
    with torch.no_grad():
        for data_dict in test_loader:
            data_dict = {k: (v.to(device) if hasattr(v, 'to') else v) for k, v in data_dict.items()}
            output = model(data_dict)
            mask = torch.tensor(data_dict['GINI'].exists, dtype=torch.bool, device=output.device).flatten()
            true = data_dict['GINI'].y[mask].cpu().numpy()
            pred = output[mask].cpu().numpy()
            all_true.append(true)
            all_pred.append(pred)
    # Concatenate results from all batches
    all_true = np.concatenate(all_true, axis=0)
    all_pred = np.concatenate(all_pred, axis=0)
    
    # Calculate metrics
    mape = mean_absolute_percentage_error(all_true, all_pred) 
    mae = mean_absolute_error(all_true, all_pred)
    rmse = np.sqrt(mean_squared_error(all_true, all_pred))
    r2 = r2_score(all_true, all_pred)

    if printing:
        print(f"Mean Absolute Error (MAE): {mae:.4f}")
        print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
        print(f"Mean Absolute Percentage Error (MAPE): {mape*100:.4f}%")
        print(f"R^2 Score: {r2:.4f}")

        # Visualization: Predicted vs True
        plt.figure(figsize=(6, 5))
        plt.scatter(all_true, all_pred, alpha=0.5)
        plt.plot([all_true.min(), all_true.max()], [all_true.min(), all_true.max()], 'r--', label="Perfect Prediction")
        plt.xlabel('True GINI')
        plt.ylabel('Predicted GINI')
        plt.title('Predicted vs True GINI (Test Set)')
        plt.legend()
        plt.tight_layout()
        plt.show()

        # Visualization: Residuals
        residuals = all_true - all_pred
        plt.figure(figsize=(6, 4))
        plt.hist(residuals, bins=30, alpha=0.7)
        plt.xlabel('Residual (True - Predicted)')
        plt.ylabel('Frequency')
        plt.title('Residuals Distribution')
        plt.tight_layout()
        plt.show()
    
    return all_true, all_pred

# %%
true, pred = evaluate_model(gan_model, test_loader, device)
# Out:
# Mean Absolute Error (MAE): 0.0203
# Root Mean Squared Error (RMSE): 0.0299
# Mean Absolute Percentage Error (MAPE): 5.4596%
# R^2 Score: 0.8740

# %%
#ATTENTION per network
attn = torch.softmax(gan_model.attn_weights, dim=0)
print(attn)
# Out:
# tensor([0.2035, 0.1931, 0.1916, 0.2108, 0.2009], device='cuda:0',
#        grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# #### Predict for countries with missing values

# %%
def predict_missing_gini_2022(model, data_years, df_gini, device, year=2022, printing=True):
    """
    Predict GINI values for countries that have missing/NaN GINI data in 2022.
    """
    model.eval()
    
    if year not in data_years:
        print(f"Year {year} not available in data")
        return None
    
    year_data = data_years[year]
    
    # Get ALL countries for 2022 from df_gini
    df_gini_2022 = df_gini[df_gini['year'] == year].copy()
    df_gini_2022['country_id'] = df_gini_2022['country'].map(lambda x: convert_country_code(x, 'UNnumeric'))
    df_gini_2022 = df_gini_2022.dropna(subset=['country_id'])
    df_gini_2022['country_id'] = df_gini_2022['country_id'].astype(int)
    
    # Countries that have valid (non-NaN) GINI data in 2022
    countries_with_valid_gini = set(df_gini_2022[df_gini_2022['gini'].notna()]['country_id'])
    
    # Countries that have missing/NaN GINI data in 2022
    countries_with_missing_gini = set(df_gini_2022[df_gini_2022['gini'].isna()]['country_id'])
    
    with torch.no_grad():
        data_dict = {k: (v.to(device) if hasattr(v, 'to') else v) for k, v in year_data.items() if k != 'GINI'}
        output = model(data_dict)
        
        # Get country IDs from any modality
        country_ids = data_dict['geography'].country_id.cpu().numpy()
        pred_gini = output.cpu().numpy().flatten()
        
        # Find countries that are in our network data AND have missing GINI values
        countries_to_predict = []
        predictions_for_missing = []
        
        for i, country_id in enumerate(country_ids):
            # Check if this country has missing GINI data in 2022
            if country_id in countries_with_missing_gini:
                countries_to_predict.append(country_id)
                predictions_for_missing.append(pred_gini[i])
        
        # check for countries that are in network data but not in GINI data at all for 2022
        all_gini_countries_2022 = set(df_gini_2022['country_id'])
        for i, country_id in enumerate(country_ids):
            if country_id not in all_gini_countries_2022:
                countries_to_predict.append(country_id)
                predictions_for_missing.append(pred_gini[i])
        
        if printing and len(countries_to_predict) > 0:
            print(f"GINI Predictions for Countries with Missing 2022 Data:")
            print(f"{'Country':<20} {'ISO3':<8} {'Predicted GINI':<15}")
            print("-" * 50)
            
            # Convert country IDs to names and ISO3 codes
            country_names = coco.convert(countries_to_predict, src="UNnumeric", to="name_short")
            iso3_codes = coco.convert(countries_to_predict, src="UNnumeric", to="ISO3")
            
            # Create results list for sorting
            results = []
            for country_id, name, iso3, pred in zip(countries_to_predict, country_names, iso3_codes, predictions_for_missing):
                results.append({
                    'country_id': country_id,
                    'name': name,
                    'iso3': iso3,
                    'predicted_gini': pred * 100  # Convert back to 0-100 scale
                })
            
            # Sort by predicted GINI (highest to lowest)
            results.sort(key=lambda x: x['predicted_gini'], reverse=True)
            
            for result in results:
                print(f"{result['name']:<20} {result['iso3']:<8} {result['predicted_gini']:<15.2f}")
            
            return results
        
        elif printing:
            print(f"All countries have GINI data available for {year}")
            return []
        
        else:
            # Return results without printing
            country_names = coco.convert(countries_to_predict, src="UNnumeric", to="name_short")
            iso3_codes = coco.convert(countries_to_predict, src="UNnumeric", to="ISO3")
            
            results = []
            for country_id, name, iso3, pred in zip(countries_to_predict, country_names, iso3_codes, predictions_for_missing):
                results.append({
                    'country_id': country_id,
                    'name': name,
                    'iso3': iso3,
                    'predicted_gini': pred * 100
                })
            
            return results

# Use your trained model to predict missing GINI values for 2022
print("="*60)
print("PREDICTING GINI FOR COUNTRIES WITH MISSING 2022 DATA")
print("="*60)

missing_gini_predictions = predict_missing_gini_2022(
    gan_model, data_years, df_gini, device, year=2022, printing=True
)
# Out:
# ============================================================
# PREDICTING GINI FOR COUNTRIES WITH MISSING 2022 DATA
# ============================================================
# GINI Predictions for Countries with Missing 2022 Data:
# Country              ISO3     Predicted GINI
# --------------------------------------------------
# Monaco               MCO      100.49
# Liechtenstein        LIE      100.11
# South Africa         ZAF      59.98
# Namibia              NAM      58.72
# Botswana             BWA      57.45
# Lesotho              LSO      54.66
# Eswatini             SWZ      53.18
# Zimbabwe             ZWE      50.87
# Panama               PAN      50.81
# Honduras             HND      49.06
# Nicaragua            NIC      47.84
# Mozambique           MOZ      46.25
# Malawi               MWI      45.62
# Bahamas              BHS      45.35
# Rwanda               RWA      44.92
# Guatemala            GTM      44.88
# DR Congo             COD      44.84
# Venezuela            VEN      44.15
# Madagascar           MDG      44.11
# Cameroon             CMR      43.82
# Philippines          PHL      43.64
# Cabo Verde           CPV      43.00
# Jamaica              JAM      42.56
# South Sudan          SSD      42.51
# Uganda               UGA      42.31
# Djibouti             DJI      42.21
# Malaysia             MYS      41.68
# Angola               AGO      41.66
# Congo Republic       COG      41.65
# Cuba                 CUB      41.60
# Central African Republic CAF      40.89
# Cambodia             KHM      40.81
# Ghana                GHA      40.78
# Brunei Darussalam    BRN      40.45
# Belize               BLZ      40.40
# Grenada              GRD      39.97
# Burundi              BDI      39.55
# Saudi Arabia         SAU      39.29
# Tanzania             TZA      39.19
# Seychelles           SYC      39.16
# Haiti                HTI      39.06
# Kenya                KEN      38.96
# Sudan                SDN      38.94
# Somalia              SOM      38.90
# North Korea          PRK      38.69
# Israel               ISR      38.58
# Comoros              COM      38.57
# Togo                 TGO      38.53
# Sri Lanka            LKA      38.24
# St. Vincent and the Grenadines VCT      38.09
# Gambia               GMB      38.03
# Eritrea              ERI      37.95
# Gabon                GAB      37.75
# St. Lucia            LCA      37.73
# Andorra              AND      37.32
# Guinea               GIN      36.97
# Burkina Faso         BFA      36.97
# Lebanon              LBN      36.96
# Laos                 LAO      36.96
# Sierra Leone         SLE      36.77
# Nigeria              NGA      36.64
# Benin                BEN      36.63
# China                CHN      36.52
# Morocco              MAR      36.20
# Trinidad and Tobago  TTO      36.07
# Senegal              SEN      36.03
# Barbados             BRB      35.89
# Russia               RUS      35.87
# Dominica             DMA      35.81
# Cote d'Ivoire        CIV      35.75
# Afghanistan          AFG      35.59
# North Macedonia      MKD      35.53
# Mali                 MLI      35.43
# Guyana               GUY      35.42
# Montenegro           MNE      35.32
# Libya                LBY      35.05
# Samoa                WSM      35.01
# Algeria              DZA      34.98
# Guinea-Bissau        GNB      34.87
# Antigua and Barbuda  ATG      34.62
# Niger                NER      34.49
# Sao Tome and Principe STP      34.41
# St. Kitts and Nevis  KNA      34.25
# Tuvalu               TUV      34.24
# Papua New Guinea     PNG      34.08
# Fiji                 FJI      33.77
# Bosnia and Herzegovina BIH      33.69
# Australia            AUS      33.67
# United Kingdom       GBR      33.64
# San Marino           SMR      33.57
# Tunisia              TUN      33.43
# Mauritius            MUS      33.37
# Oman                 OMN      33.26
# Marshall Islands     MHL      33.12
# South Korea          KOR      33.04
# Liberia              LBR      33.03
# Singapore            SGP      32.92
# Japan                JPN      32.74
# Canada               CAN      32.63
# Tonga                TON      32.02
# Germany              DEU      31.96
# Switzerland          CHE      31.93
# Ethiopia             ETH      31.31
# United Arab Emirates ARE      30.96
# New Zealand          NZL      30.91
# Kuwait               KWT      30.58
# Nauru                NRU      30.42
# Jordan               JOR      30.27
# Myanmar              MMR      30.03
# Qatar                QAT      29.99
# Pakistan             PAK      29.88
# Albania              ALB      29.51
# Egypt                EGY      29.25
# Mauritania           MRT      28.73
# Yemen                YEM      28.42
# Timor-Leste          TLS      28.41
# Bahrain              BHR      28.25
# Kazakhstan           KAZ      28.23
# Netherlands          NLD      28.21
# Maldives             MDV      28.13
# Kiribati             KIR      27.50
# Iraq                 IRQ      27.36
# Palau                PLW      26.85
# Vanuatu              VUT      26.51
# Micronesia, Fed. Sts. FSM      26.21
# Solomon Islands      SLB      26.03
# Iceland              ISL      25.99
# Azerbaijan           AZE      24.95
# Belarus              BLR      24.21
# Ukraine              UKR      23.66
# Tajikistan           TJK      22.50
# Turkmenistan         TKM      22.20

# %%
df_missing_gini_pred = pd.DataFrame(missing_gini_predictions)

df_missing_gini_pred.to_csv('/home/jovyan/dlss-project/df_missing_gini_pred_without_gini.csv')

# %% [markdown]
# ### Evaluating on test countries without a gini in 2022

# %%
# load dataset
df_gini2021 = df_gini[df_gini['year'].between(2000, 2022)].reset_index(drop=True)

# %%
# Define your test countries
test_countries = ["FRA", "POL", "SWE", "IND", "IRN", "IDN", 
                  "ZMB", "TCD", "USA", "BRA", "MEX", "BTN", "MLT", "SUR"]
test_countries_numeric = coco.convert(test_countries, to="UNnumeric")

# Create a version of df_gini with specific countries' GINI data removed
def create_gini_data_excluding_test_countries(df_gini, test_countries_numeric, year_col='year', country_col='country', gini_col='gini'):
    """
    Create GINI data where test countries have their GINI values set to NaN/missing,
    but other countries keep their real GINI values for all years including 2022.
    """
    uno_iso3_codes, _ = get_un_countries()
    df_gini_modified = df_gini.copy()
    
    # Convert country codes to numeric for comparison
    df_gini_modified['country_id'] = df_gini_modified[country_col].map(lambda x: convert_country_code(x, 'UNnumeric'))
    
    # Set GINI values to NaN for test countries (this simulates missing data)
    test_mask = df_gini_modified['country_id'].isin(test_countries_numeric)
    df_gini_modified.loc[test_mask, gini_col] = np.nan
    
    # Continue with normal processing
    df_gini_modified = df_gini_modified[df_gini_modified[country_col].isin(uno_iso3_codes)].copy()
    df_gini_modified = df_gini_modified.sort_values(by=['country_id']).reset_index(drop=True)
    df_gini_modified = df_gini_modified.dropna(subset=['country_id'])
    df_gini_modified[gini_col] = df_gini_modified[gini_col] / 100  # Normalize to [0,1]
    df_gini_modified['exists'] = 1
    df_gini_modified.loc[df_gini_modified[gini_col].isna(), 'exists'] = 0
    df_gini_modified.loc[df_gini_modified[gini_col].isna(), gini_col] = 0

    gini_data_dict = {}
    years = df_gini_modified[year_col].unique()
    for year in years:
        df_year = df_gini_modified[df_gini_modified[year_col] == year].copy()
        df_year['country_id'] = df_year['country_id'].astype(int)
        gini_tensor = torch.tensor(df_year[gini_col].values, dtype=torch.float32)
        country_id_tensor = torch.tensor(df_year['country_id'].values, dtype=torch.long)
        data = Data(y=gini_tensor.unsqueeze(1), country_id=country_id_tensor, exists=df_year['exists'].values)
        gini_data_dict[year] = data
    return gini_data_dict

# Create modified GINI data (excluding test countries)
gini_data_modified = create_gini_data_excluding_test_countries(df_gini, test_countries_numeric)

# Rebuild data_years with modified GINI data
data_years_modified = {}
common_years = sorted(set(geo_data.keys()) & set(pol_data.keys()) & set(cul_data.keys()) & set(lang_data.keys()) & set(eco_data.keys()))

for year in common_years:
    data_years_modified[year] = {
        'geography': geo_data[year],
        'political': pol_data[year], 
        'culture': cul_data[year],
        'language': lang_data[year],
        'economy': eco_data[year],
        'GINI': gini_data_modified.get(year)  
    }

# Create train/val/test splits using all years (including 2022)
all_years_modified = sorted([y for y in data_years_modified.keys() if data_years_modified[y]['GINI'] is not None])
train_years_modified, test_years_modified = train_test_split(all_years_modified, test_size=0.2, random_state=42)
train_years_modified, val_years_modified = train_test_split(train_years_modified, test_size=0.25, random_state=42)

train_set_modified = [data_years_modified[y] for y in train_years_modified]
val_set_modified = [data_years_modified[y] for y in val_years_modified]
test_set_modified = [data_years_modified[y] for y in test_years_modified]

print(f"Training on {len(train_set_modified)} years, validating on {len(val_set_modified)} years, testing on {len(test_set_modified)} years")
print(f"Years include data up to: {max(all_years_modified)}")
# Out:
# Training on 13 years, validating on 5 years, testing on 5 years
# Years include data up to: 2022

# %%
# retrain
train_set_modified = [move_data_dict_to_device(d, device) for d in train_set_modified]
val_set_modified = [move_data_dict_to_device(d, device) for d in val_set_modified]
test_set_modified = [move_data_dict_to_device(d, device) for d in test_set_modified]

train_loader_modified = DataLoader(train_set_modified, batch_size=1, shuffle=True)
val_loader_modified = DataLoader(val_set_modified, batch_size=1, shuffle=False)

# new model
gan_model_modified = MultiModalGNNModel(
    input_dims=network_dimesions, hidden_size=148, n_dim_mlp_layers=0, 
    combination_method="attention", mlp_variant="deep", n_gat_layers=1
)
gan_model_modified = gan_model_modified.to(device)

criterion = nn.L1Loss()
optimizer = optim.Adam(gan_model_modified.parameters(), lr=0.0006502342591153078, weight_decay=0.0000003414375524585915)
early_stopper = EarlyStopping(patience=60, min_delta=0.0001, path='model_checkpoints/gan_checkpoint_modified.pt')

print("Training model with test countries' GINI data excluded...")
train_losses_modified, val_losses_modified = train_gnn(
    1000, gan_model_modified, optimizer, criterion, 
    train_loader_modified, val_loader_modified, early_stopper
)

# Plot results
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses_gan, label='Training Loss')
plt.plot(val_losses_gan, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Progress')
# Out:
# Removing existing model at: model_checkpoints/gan_checkpoint_modified.pt
# Training model with test countries' GINI data excluded...
# Starting training...
# Epoch: 1, Training Loss: 0.3469, Validation Loss: 0.1694
# Validation loss decreased (0.169350 --> 0.169350).  Saving model ...
# Epoch: 2, Training Loss: 0.2508, Validation Loss: 0.0685
# Validation loss decreased (0.169350 --> 0.068492).  Saving model ...
# Epoch: 3, Training Loss: 0.2029, Validation Loss: 0.0706
# Epoch: 4, Training Loss: 0.1539, Validation Loss: 0.0613
# Validation loss decreased (0.068492 --> 0.061293).  Saving model ...
# Epoch: 5, Training Loss: 0.1320, Validation Loss: 0.0539
# Validation loss decreased (0.061293 --> 0.053882).  Saving model ...
# Epoch: 6, Training Loss: 0.1361, Validation Loss: 0.0691
# Epoch: 7, Training Loss: 0.1218, Validation Loss: 0.0603
# Epoch: 8, Training Loss: 0.0913, Validation Loss: 0.0734
# Epoch: 9, Training Loss: 0.1201, Validation Loss: 0.0573
# Epoch: 10, Training Loss: 0.0746, Validation Loss: 0.0442
# Validation loss decreased (0.053882 --> 0.044167).  Saving model ...
# Epoch: 11, Training Loss: 0.0869, Validation Loss: 0.0661
# Epoch: 12, Training Loss: 0.0760, Validation Loss: 0.0460
# Epoch: 13, Training Loss: 0.0705, Validation Loss: 0.0510
# Epoch: 14, Training Loss: 0.0387, Validation Loss: 0.0440
# Validation loss decreased (0.044167 --> 0.043978).  Saving model ...
# Epoch: 15, Training Loss: 0.0489, Validation Loss: 0.0536
# Epoch: 16, Training Loss: 0.0481, Validation Loss: 0.0359
# Validation loss decreased (0.043978 --> 0.035850).  Saving model ...
# Epoch: 17, Training Loss: 0.0566, Validation Loss: 0.0479
# Epoch: 18, Training Loss: 0.0399, Validation Loss: 0.0383
# Epoch: 19, Training Loss: 0.0424, Validation Loss: 0.0408
# Epoch: 20, Training Loss: 0.0716, Validation Loss: 0.0358
# Epoch: 21, Training Loss: 0.0448, Validation Loss: 0.0444
# Epoch: 22, Training Loss: 0.0394, Validation Loss: 0.0466
# Epoch: 23, Training Loss: 0.0385, Validation Loss: 0.0365
# Epoch: 24, Training Loss: 0.0440, Validation Loss: 0.0319
# Validation loss decreased (0.035850 --> 0.031941).  Saving model ...
# Epoch: 25, Training Loss: 0.0430, Validation Loss: 0.0386
# Epoch: 26, Training Loss: 0.0489, Validation Loss: 0.0346
# Epoch: 27, Training Loss: 0.0381, Validation Loss: 0.0375
# Epoch: 28, Training Loss: 0.0317, Validation Loss: 0.0354
# Epoch: 29, Training Loss: 0.0329, Validation Loss: 0.0342
# Epoch: 30, Training Loss: 0.0310, Validation Loss: 0.0379
# Epoch: 31, Training Loss: 0.0335, Validation Loss: 0.0328
# Epoch: 32, Training Loss: 0.0337, Validation Loss: 0.0347
# Epoch: 33, Training Loss: 0.0372, Validation Loss: 0.0373
# Epoch: 34, Training Loss: 0.0278, Validation Loss: 0.0357
# Epoch: 35, Training Loss: 0.0351, Validation Loss: 0.0367
# Epoch: 36, Training Loss: 0.0274, Validation Loss: 0.0303
# Validation loss decreased (0.031941 --> 0.030309).  Saving model ...
# Epoch: 37, Training Loss: 0.0344, Validation Loss: 0.0347
# Epoch: 38, Training Loss: 0.0319, Validation Loss: 0.0356
# Epoch: 39, Training Loss: 0.0339, Validation Loss: 0.0380
# Epoch: 40, Training Loss: 0.0299, Validation Loss: 0.0318
# Epoch: 41, Training Loss: 0.0222, Validation Loss: 0.0389
# Epoch: 42, Training Loss: 0.0250, Validation Loss: 0.0373
# Epoch: 43, Training Loss: 0.0324, Validation Loss: 0.0342
# Epoch: 44, Training Loss: 0.0325, Validation Loss: 0.0393
# Epoch: 45, Training Loss: 0.0277, Validation Loss: 0.0297
# Validation loss decreased (0.030309 --> 0.029677).  Saving model ...
# Epoch: 46, Training Loss: 0.0317, Validation Loss: 0.0338
# Epoch: 47, Training Loss: 0.0401, Validation Loss: 0.0371
# Epoch: 48, Training Loss: 0.0373, Validation Loss: 0.0348
# Epoch: 49, Training Loss: 0.0191, Validation Loss: 0.0328
# Epoch: 50, Training Loss: 0.0308, Validation Loss: 0.0333
# Epoch: 51, Training Loss: 0.0274, Validation Loss: 0.0337
# Epoch: 52, Training Loss: 0.0232, Validation Loss: 0.0301
# Epoch: 53, Training Loss: 0.0232, Validation Loss: 0.0270
# Validation loss decreased (0.029677 --> 0.026954).  Saving model ...
# Epoch: 54, Training Loss: 0.0308, Validation Loss: 0.0271
# Epoch: 55, Training Loss: 0.0231, Validation Loss: 0.0334
# Epoch: 56, Training Loss: 0.0368, Validation Loss: 0.0340
# Epoch: 57, Training Loss: 0.0291, Validation Loss: 0.0329
# Epoch: 58, Training Loss: 0.0311, Validation Loss: 0.0335
# Epoch: 59, Training Loss: 0.0275, Validation Loss: 0.0312
# Epoch: 60, Training Loss: 0.0257, Validation Loss: 0.0391
# Epoch: 61, Training Loss: 0.0286, Validation Loss: 0.0350
# Epoch: 62, Training Loss: 0.0283, Validation Loss: 0.0289
# Epoch: 63, Training Loss: 0.0325, Validation Loss: 0.0315
# Epoch: 64, Training Loss: 0.0400, Validation Loss: 0.0371
# Epoch: 65, Training Loss: 0.0207, Validation Loss: 0.0270
# Epoch: 66, Training Loss: 0.0283, Validation Loss: 0.0364
# Epoch: 67, Training Loss: 0.0254, Validation Loss: 0.0306
# Epoch: 68, Training Loss: 0.0235, Validation Loss: 0.0299
# Epoch: 69, Training Loss: 0.0246, Validation Loss: 0.0313
# Epoch: 70, Training Loss: 0.0304, Validation Loss: 0.0397
# Epoch: 71, Training Loss: 0.0279, Validation Loss: 0.0383
# Epoch: 72, Training Loss: 0.0245, Validation Loss: 0.0304
# Epoch: 73, Training Loss: 0.0215, Validation Loss: 0.0284
# Epoch: 74, Training Loss: 0.0195, Validation Loss: 0.0302
# Epoch: 75, Training Loss: 0.0286, Validation Loss: 0.0297
# Epoch: 76, Training Loss: 0.0264, Validation Loss: 0.0349
# Epoch: 77, Training Loss: 0.0223, Validation Loss: 0.0354
# Epoch: 78, Training Loss: 0.0180, Validation Loss: 0.0258
# Validation loss decreased (0.026954 --> 0.025844).  Saving model ...
# Epoch: 79, Training Loss: 0.0212, Validation Loss: 0.0288
# Epoch: 80, Training Loss: 0.0200, Validation Loss: 0.0256
# Validation loss decreased (0.025844 --> 0.025573).  Saving model ...
# Epoch: 81, Training Loss: 0.0246, Validation Loss: 0.0294
# Epoch: 82, Training Loss: 0.0256, Validation Loss: 0.0312
# Epoch: 83, Training Loss: 0.0209, Validation Loss: 0.0318
# Epoch: 84, Training Loss: 0.0229, Validation Loss: 0.0293
# Epoch: 85, Training Loss: 0.0255, Validation Loss: 0.0323
# Epoch: 86, Training Loss: 0.0285, Validation Loss: 0.0283
# Epoch: 87, Training Loss: 0.0162, Validation Loss: 0.0319
# Epoch: 88, Training Loss: 0.0192, Validation Loss: 0.0306
# Epoch: 89, Training Loss: 0.0200, Validation Loss: 0.0332
# Epoch: 90, Training Loss: 0.0209, Validation Loss: 0.0318
# Epoch: 91, Training Loss: 0.0205, Validation Loss: 0.0299
# Epoch: 92, Training Loss: 0.0222, Validation Loss: 0.0266
# Epoch: 93, Training Loss: 0.0208, Validation Loss: 0.0268
# Epoch: 94, Training Loss: 0.0251, Validation Loss: 0.0298
# Epoch: 95, Training Loss: 0.0200, Validation Loss: 0.0252
# Validation loss decreased (0.025573 --> 0.025220).  Saving model ...
# Epoch: 96, Training Loss: 0.0240, Validation Loss: 0.0257
# Epoch: 97, Training Loss: 0.0184, Validation Loss: 0.0282
# Epoch: 98, Training Loss: 0.0255, Validation Loss: 0.0257
# Epoch: 99, Training Loss: 0.0264, Validation Loss: 0.0279
# Epoch: 100, Training Loss: 0.0234, Validation Loss: 0.0280
# Epoch: 101, Training Loss: 0.0224, Validation Loss: 0.0315
# Epoch: 102, Training Loss: 0.0249, Validation Loss: 0.0219
# Validation loss decreased (0.025220 --> 0.021931).  Saving model ...
# Epoch: 103, Training Loss: 0.0130, Validation Loss: 0.0299
# Epoch: 104, Training Loss: 0.0188, Validation Loss: 0.0280
# Epoch: 105, Training Loss: 0.0251, Validation Loss: 0.0268
# Epoch: 106, Training Loss: 0.0214, Validation Loss: 0.0280
# Epoch: 107, Training Loss: 0.0169, Validation Loss: 0.0242
# Epoch: 108, Training Loss: 0.0194, Validation Loss: 0.0248
# Epoch: 109, Training Loss: 0.0244, Validation Loss: 0.0262
# Epoch: 110, Training Loss: 0.0213, Validation Loss: 0.0268
# Epoch: 111, Training Loss: 0.0158, Validation Loss: 0.0285
# Epoch: 112, Training Loss: 0.0194, Validation Loss: 0.0260
# Epoch: 113, Training Loss: 0.0237, Validation Loss: 0.0245
# Epoch: 114, Training Loss: 0.0273, Validation Loss: 0.0272
# Epoch: 115, Training Loss: 0.0209, Validation Loss: 0.0294
# Epoch: 116, Training Loss: 0.0212, Validation Loss: 0.0240
# Epoch: 117, Training Loss: 0.0211, Validation Loss: 0.0268
# Epoch: 118, Training Loss: 0.0214, Validation Loss: 0.0264
# Epoch: 119, Training Loss: 0.0191, Validation Loss: 0.0263
# Epoch: 120, Training Loss: 0.0190, Validation Loss: 0.0252
# Epoch: 121, Training Loss: 0.0213, Validation Loss: 0.0252
# Epoch: 122, Training Loss: 0.0192, Validation Loss: 0.0256
# Epoch: 123, Training Loss: 0.0193, Validation Loss: 0.0276
# Epoch: 124, Training Loss: 0.0163, Validation Loss: 0.0245
# Epoch: 125, Training Loss: 0.0210, Validation Loss: 0.0256
# Epoch: 126, Training Loss: 0.0128, Validation Loss: 0.0238
# Epoch: 127, Training Loss: 0.0177, Validation Loss: 0.0276
# Epoch: 128, Training Loss: 0.0179, Validation Loss: 0.0265
# Epoch: 129, Training Loss: 0.0188, Validation Loss: 0.0267
# Epoch: 130, Training Loss: 0.0235, Validation Loss: 0.0257
# Epoch: 131, Training Loss: 0.0180, Validation Loss: 0.0246
# Epoch: 132, Training Loss: 0.0172, Validation Loss: 0.0257
# Epoch: 133, Training Loss: 0.0185, Validation Loss: 0.0254
# Epoch: 134, Training Loss: 0.0165, Validation Loss: 0.0249
# Epoch: 135, Training Loss: 0.0157, Validation Loss: 0.0238
# Epoch: 136, Training Loss: 0.0181, Validation Loss: 0.0252
# Epoch: 137, Training Loss: 0.0176, Validation Loss: 0.0247
# Epoch: 138, Training Loss: 0.0177, Validation Loss: 0.0247
# Epoch: 139, Training Loss: 0.0159, Validation Loss: 0.0286
# Epoch: 140, Training Loss: 0.0179, Validation Loss: 0.0241
# Epoch: 141, Training Loss: 0.0166, Validation Loss: 0.0237
# Epoch: 142, Training Loss: 0.0178, Validation Loss: 0.0260
# Epoch: 143, Training Loss: 0.0156, Validation Loss: 0.0244
# Epoch: 144, Training Loss: 0.0182, Validation Loss: 0.0251
# Epoch: 145, Training Loss: 0.0198, Validation Loss: 0.0260
# Epoch: 146, Training Loss: 0.0193, Validation Loss: 0.0252
# Epoch: 147, Training Loss: 0.0141, Validation Loss: 0.0222
# Epoch: 148, Training Loss: 0.0154, Validation Loss: 0.0222
# Epoch: 149, Training Loss: 0.0198, Validation Loss: 0.0260
# Epoch: 150, Training Loss: 0.0190, Validation Loss: 0.0255
# Epoch: 151, Training Loss: 0.0186, Validation Loss: 0.0261
# Epoch: 152, Training Loss: 0.0166, Validation Loss: 0.0241
# Epoch: 153, Training Loss: 0.0173, Validation Loss: 0.0273
# Epoch: 154, Training Loss: 0.0161, Validation Loss: 0.0246
# Epoch: 155, Training Loss: 0.0144, Validation Loss: 0.0241
# Epoch: 156, Training Loss: 0.0185, Validation Loss: 0.0246
# Epoch: 157, Training Loss: 0.0137, Validation Loss: 0.0258
# Epoch: 158, Training Loss: 0.0180, Validation Loss: 0.0242
# Epoch: 159, Training Loss: 0.0172, Validation Loss: 0.0254
# Epoch: 160, Training Loss: 0.0208, Validation Loss: 0.0251
# Epoch: 161, Training Loss: 0.0138, Validation Loss: 0.0246
# Epoch: 162, Training Loss: 0.0174, Validation Loss: 0.0246
# Early stopping triggered.
# Text(0.5, 1.0, 'Training Progress')

# %%
def evaluate_specific_countries_with_plot(model, data_years, test_countries_numeric, device, year=2022, printing=True):
    """
    Evaluate the model on specific test countries for a given year with visualization.
    """
    model.eval()
    
    if year not in data_years:
        print(f"Year {year} not available in data")
        return None, None
    
    year_data = data_years[year]
    
    with torch.no_grad():
        data_dict = {k: (v.to(device) if hasattr(v, 'to') else v) for k, v in year_data.items() if k != 'GINI'}
        output = model(data_dict)
        
        # get country ids
        country_ids = data_dict['geography'].country_id.cpu().numpy()
        pred_gini = output.cpu().numpy().flatten()
        
        # filter test countries
        test_country_mask = np.isin(country_ids, test_countries_numeric)
        
        if not np.any(test_country_mask):
            print(f"No test countries found in {year} data")
            return None, None
        
        test_country_ids = country_ids[test_country_mask]
        test_pred = pred_gini[test_country_mask]
        
        # Get true GINI values from df_gini
        df_gini_year = df_gini[df_gini['year'] == year].copy()
        df_gini_year['country_id'] = df_gini_year['country'].map(lambda x: convert_country_code(x, 'UNnumeric'))
        df_gini_year = df_gini_year.dropna(subset=['country_id'])
        df_gini_year['country_id'] = df_gini_year['country_id'].astype(int)
        
        # Create mapping from country_id to true GINI
        country_to_gini = dict(zip(df_gini_year['country_id'], df_gini_year['gini'] / 100))  # Normalize to [0,1]
        
        # Get true values for test countries
        true_values = []
        available_country_ids = []
        available_predictions = []
        
        for i, country_id in enumerate(test_country_ids):
            if country_id in country_to_gini:
                true_values.append(country_to_gini[country_id])
                available_country_ids.append(country_id)
                available_predictions.append(test_pred[i])
        
        if printing and len(available_country_ids) > 0:
            print(f"Predictions vs True Values for Test Countries ({year}):")
            print(f"{'Country':<8} {'True GINI':<12} {'Predicted':<12} {'Difference':<12}")
            print("-" * 50)
            
            iso3_labels = coco.convert(available_country_ids, src="UNnumeric", to="ISO3")
            for country_id, true_val, pred_val, iso in zip(available_country_ids, true_values, available_predictions, iso3_labels):
                diff = pred_val - true_val
                print(f"{iso:<8} {true_val:<12.4f} {pred_val:<12.4f} {diff:<12.4f}")
            
            # calculate metrics
            true_array = np.array(true_values)
            pred_array = np.array(available_predictions)
            
            mse = mean_squared_error(true_array, pred_array)
            rmse = np.sqrt(mse)
            mae = mean_absolute_error(true_array, pred_array)
            r2 = r2_score(true_array, pred_array)
            mape = mean_absolute_percentage_error(true_array, pred_array)
            
            print(f"\nGNN Model Performance on Test Countries ({year}):")
            print(f"MSE: {mse:.4f}")
            print(f"RMSE: {rmse:.4f}")
            print(f"MAE: {mae:.4f}")
            print(f"MAPE: {mape:.4f}%")
            print(f"R²: {r2:.4f}")
            

            # plot predicted vs true
            plt.figure(figsize=(6, 5))
            plt.scatter(true_array, pred_array, alpha=0.7)
            for i, country in enumerate(iso3_labels):
                plt.annotate(country, (true_values[i], available_predictions[i]), 
                    xytext=(5, 5), textcoords='offset points', 
                    fontsize=9, alpha=0.8)
            
            min_val = min(true_array.min(), pred_array.min())
            max_val = max(true_array.max(), pred_array.max())
            plt.plot([min_val, max_val], [min_val, max_val], '--r', alpha=0.8, label='Perfect Prediction')
            
            plt.xlabel("True GINI")
            plt.ylabel("Predicted GINI")
            plt.title(f"GNN Model: Predicted vs True GINI for Test Countries")
            plt.legend()
            plt.tight_layout()
            plt.show()
        
        elif printing:
            print(f"No true GINI values available for test countries in {year}")
                
        return test_country_ids, test_pred

# Define test countries and run evaluation
test_countries = ["FRA", "POL", "SWE", "IND", "IRN", "IDN", 
                  "ZMB", "TCD", "USA", "BRA", "MEX", "BTN", "MLT", "SUR"]
test_countries_numeric = coco.convert(test_countries, to="UNnumeric")

print("GNN MODEL PREDICTIONS FOR TEST COUNTRIES (2022)")

# Use the modified model that was trained WITHOUT test countries' GINI data
test_country_ids, test_predictions = evaluate_specific_countries_with_plot(
    gan_model_modified, data_years, test_countries_numeric, device, year=2022, printing=True
)
# Out:
# GNN MODEL PREDICTIONS FOR TEST COUNTRIES (2022)
# Predictions vs True Values for Test Countries (2022):
# Country  True GINI    Predicted    Difference
# --------------------------------------------------
# BTN      0.2850       0.4228       0.1378
# BRA      0.5200       0.4284       -0.0916
# TCD      0.3740       0.4192       0.0452
# FRA      0.3120       0.3504       0.0384
# IND      0.2550       0.4328       0.1778
# IDN      0.3550       0.4067       0.0517
# IRN      0.3480       0.3643       0.0163
# MLT      0.3460       0.3413       -0.0047
# MEX      0.4350       0.4780       0.0430
# POL      0.2890       0.2703       -0.0187
# SUR      0.3920       0.4268       0.0348
# SWE      0.3160       0.2861       -0.0299
# USA      0.4170       0.3460       -0.0710
# ZMB      0.5150       0.3960       -0.1190
#
# GNN Model Performance on Test Countries (2022):
# MSE: 0.0064
# RMSE: 0.0797
# MAE: 0.0629
# MAPE: 0.1825%
# R²: -0.0470

# %% [markdown]
# ## Hyperparameter Tuning with Optuna

# %%
import optuna

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def move_data_dict_to_device(data_dict, device):
    moved = {}
    for k, v in data_dict.items():
        if hasattr(v, 'to'):
            moved[k] = v.to(device)
        else:
            moved[k] = v
    return moved

train_set = [move_data_dict_to_device(d, device) for d in train_set]
val_set = [move_data_dict_to_device(d, device) for d in val_set]
test_set = [move_data_dict_to_device(d, device) for d in test_set]


def objective(trial):
    
    hidden_size = trial.suggest_int("hidden_size", 20, 300, step=16)
    weight_decay = trial.suggest_float("weight_decay", 1e-7, 1e-3, log=True)
    lr = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    
    n_gat_layers = trial.suggest_int("n_gat_layers", 1, 3)
    n_dim_mlp_layers = trial.suggest_int("n_dim_mlp_layers", 0, 3)
    combination_method = trial.suggest_categorical("combination_method", ['concat', 'attention'])
    batch_size = trial.suggest_int("batch_size", 2, 8, step=1)
    
    mlp_variant = trial.suggest_categorical("mlp_variant", ['default', 'deep', 'shallow'])


    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
    # test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)
    
    gan_model = MultiModalGNNModel(
        input_dims=network_dimesions, hidden_size=hidden_size,
        n_gat_layers=n_gat_layers, n_dim_mlp_layers=n_dim_mlp_layers,
        combination_method=combination_method,
        mlp_variant=mlp_variant)
    
    gan_model = gan_model.to(device)
    
    # criterion for regression task
    criterion = nn.L1Loss()
    
    # Fix 7: Better optimizer settings for this problem
    optimizer = optim.Adam(gan_model.parameters(), lr=lr, weight_decay=weight_decay)  # Lower LR and weight decay
    
    # Initialize early stopping
    early_stopper = EarlyStopping(patience=30, min_delta=0.00001, path='model_checkpoints/gan_checkpoint_optuna.pt', printing=False)
    
    # Train the model
    epochs = 1000
    train_losses_gan, val_losses_gan = train_gnn(epochs, gan_model, optimizer, criterion, train_loader, val_loader, early_stopper, printing=False)
    
    # Evaluate the model on the validation set
    true, pred = evaluate_model(gan_model, val_loader, device, printing =False)
    mae = mean_absolute_error(true, pred)
    
    return mae

study = optuna.create_study(
    study_name = "Multimodal_base",
    storage="sqlite:///optuna_study_optimized.db",
    direction="minimize",
    load_if_exists=True)
# study.optimize(objective, n_trials=50) # comment out to run new trial

print("Best trial:")
print(study.best_trial.params)
# Out:
# [I 2025-08-27 15:32:30,987] Using an existing study with name 'Multimodal_base' instead of creating a new one.
# Best trial:
# {'hidden_size': 148, 'weight_decay': 3.414375524585915e-07, 'lr': 0.0006502342591153078, 'n_gat_layers': 1, 'n_dim_mlp_layers': 0, 'combination_method': 'attention', 'batch_size': 3, 'mlp_variant': 'deep'}

# %% [markdown]
# best performance with deep MLP and only 1 GAT layer..... maybe network is not soooo important after all....
